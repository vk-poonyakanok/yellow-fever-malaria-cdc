# %%
import sys
import requests
import bs4  # BeautifulSoup is part of bs4 package
import pandas as pd
import re
import plotly
import IPython

# %%
# Print Python version
print(f"Python Version: {sys.version}")

# Print library versions
print(f"Requests Version: {requests.__version__}")
print(f"BeautifulSoup Version: {bs4.__version__}")
print(f"Pandas Version: {pd.__version__}")
print(f"Plotly Version: {plotly.__version__}")
print(f"IPython Version: {IPython.__version__}")
# Out:
# Python Version: 3.12.2 | packaged by conda-forge | (main, Feb 16 2024, 20:54:21) [Clang 16.0.6 ]
# Requests Version: 2.32.2
# BeautifulSoup Version: 4.12.3
# Pandas Version: 2.2.2
# Plotly Version: 5.22.0
# IPython Version: 8.25.0

# %%
from bs4 import BeautifulSoup

# Define the URL
url = "https://wwwnc.cdc.gov/travel/yellowbook/2024/preparing/yellow-fever-vaccine-malaria-prevention-by-country"

# Fetch the webpage
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Locate all country blocks
country_blocks = soup.find_all("div", class_="dyfm-block")

# Function to clean extracted text while preserving reference numbers
def clean_text(text):
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces/newlines with a single space
    return text.strip()

# Function to format lists with newlines
def format_list(ul_element):
    return "\n".join([li.get_text(strip=True) for li in ul_element.find_all("li")]) if ul_element else ""

# Initialize a list to store extracted data
data_list = []

# Loop through each country section
for country in country_blocks:
    country_name = country.find("h2").get_text(strip=True) if country.find("h2") else ""

    # Initialize extracted data dictionary (empty values instead of "Not Found")
    extracted_data = {
        "Country": country_name,
        "Entry Requirements": "",
        "CDC Recommendations": "",
        "Transmission Areas": "",
        "Drug Resistance": "",
        "Species": "",
        "Recommended Chemoprophylaxis": "",
        "Last Updated": ""
    }

    # Extract Entry Requirements
    paragraphs = country.find_all("p")
    for para in paragraphs:
        strong_tag = para.find("strong")
        if strong_tag:
            strong_text = strong_tag.get_text(strip=True)
            if "Entry requirements" in strong_text:
                entry_text = para.get_text(strip=True).replace("Entry requirements:", "").strip()
                extracted_data["Entry Requirements"] = clean_text(entry_text)

    # Extract CDC Recommendations
    recommended = ""
    generally_not_recommended = ""
    not_recommended = ""

    # Find the paragraph that contains "CDC recommendations"
    cdc_recommendations_p = None
    for para in paragraphs:
        if "CDC recommendations" in para.get_text(strip=True):
            cdc_recommendations_p = para
            break

    if cdc_recommendations_p:
        full_text = cdc_recommendations_p.get_text(" ", strip=True).replace("CDC recommendations:", "").strip()

        # Find all bold elements inside the CDC recommendations
        bold_tags = cdc_recommendations_p.find_all("strong")

        # Create a mapping of recommendation types
        recommendation_sections = {}

        for bold in bold_tags:
            bold_text = bold.get_text(strip=True)
            start_idx = full_text.find(bold_text)
            if start_idx != -1:
                recommendation_sections[bold_text] = start_idx

        # Sort by position in text
        sorted_recommendations = sorted(recommendation_sections.items(), key=lambda x: x[1])

        # Extract each recommendation text based on its position
        extracted_texts = {}
        for i, (label, start_idx) in enumerate(sorted_recommendations):
            end_idx = sorted_recommendations[i + 1][1] if i + 1 < len(sorted_recommendations) else len(full_text)
            extracted_texts[label] = full_text[start_idx + len(label):end_idx].strip()

        # Assign extracted recommendations
        recommended = extracted_texts.get("Recommended", "").strip()
        generally_not_recommended = extracted_texts.get("Generally not recommended", "").strip()
        not_recommended = extracted_texts.get("Not recommended", "").strip()

        # Format recommendations correctly with newlines
        cdc_recommendations = []
        if recommended:
            cdc_recommendations.append(f"Recommended: {recommended}")
        if generally_not_recommended:
            cdc_recommendations.append(f"Generally not recommended: {generally_not_recommended}")
        if not_recommended:
            cdc_recommendations.append(f"Not recommended: {not_recommended}")

        extracted_data["CDC Recommendations"] = "\n".join(cdc_recommendations)

    # Extract Malaria Information
    for para in paragraphs:
        strong_tag = para.find("strong")
        if strong_tag:
            strong_text = strong_tag.get_text(strip=True)
            next_ul = para.find_next("ul")  # Locate the closest <ul> element

            if "Transmission areas" in strong_text and next_ul:
                extracted_data["Transmission Areas"] = format_list(next_ul)

            elif "Drug resistance" in strong_text and next_ul:
                extracted_data["Drug Resistance"] = format_list(next_ul)

            elif "Species" in strong_text and next_ul:
                extracted_data["Species"] = format_list(next_ul)

            elif "Recommended chemoprophylaxis" in strong_text and next_ul:
                extracted_data["Recommended Chemoprophylaxis"] = format_list(next_ul)

    # Extract Last Updated Date
    last_updated = country.find("div", class_="LastDateUpdate")
    if last_updated:
        last_updated_text = last_updated.get_text(strip=True).replace("Date last updated:", "").strip()
        extracted_data["Last Updated"] = last_updated_text  # Keep full date

    # Append extracted data to list
    data_list.append(extracted_data)

# Convert to DataFrame
df = pd.DataFrame(data_list)

# # Save to CSV
# df.to_csv("yellow_fever_malaria_data_cleaned.csv", index=False)

# Display the extracted DataFrame
from IPython.display import display
display(df.head(10))
# Out:
#                 Country                                 Entry Requirements  \
# 0           Afghanistan                                               None
# 1               Albania  Required for travelers ≥1 year old arriving fr...
# 2               Algeria  Required for travelers ≥9 months old arriving ...
# 3  American Samoa  (US)                                               None
# 4               Andorra                                               None
# 5                Angola      Required for arriving travelers ≥9 months old
# 6       Anguilla (U.K.)                                               None
# 7            Antarctica                                               None
# 8   Antigua and Barbuda  Required for travelers ≥1 year old arriving fr...
# 9             Argentina                                               None
#
#                                  CDC Recommendations  \
# 0
# 1
# 2
# 3
# 4
# 5       Recommended: for all travelers ≥9 months old
# 6
# 7
# 8
# 9  Recommended: for travelers ≥9 months old going...
#
#                                   Transmission Areas Drug Resistance  \
# 0  All areas <2,500 m (≈8,200 ft) elevation (Apri...     Chloroquine
# 1
# 2
# 3
# 4
# 5                                                All     Chloroquine
# 6
# 7
# 8
# 9
#
#                                              Species  \
# 0  P. vivax(primarily)\nP. falciparum(less commonly)
# 1
# 2
# 3
# 4
# 5  P. falciparum(primarily)\nP. malariae,P. ovale...
# 6
# 7
# 8
# 9
#
#                         Recommended Chemoprophylaxis     Last Updated
# 0  Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
# 1                                                     October 4, 2024
# 2                                                     October 4, 2024
# 3                                                     October 4, 2024
# 4                                                     October 4, 2024
# 5  Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
# 6                                                     October 4, 2024
# 7                                                     October 4, 2024
# 8                                                     October 4, 2024
# 9                                                     October 4, 2024

# %%
df[df["Country"] == "Argentina"]
# Out:
#      Country Entry Requirements  \
# 9  Argentina               None
#
#                                  CDC Recommendations Transmission Areas  \
# 9  Recommended: for travelers ≥9 months old going...
#
#   Drug Resistance Species Recommended Chemoprophylaxis     Last Updated
# 9                                                       October 4, 2024

# %%
data_list
# Out:
# [{'Country': 'Afghanistan',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'All areas <2,500 m (≈8,200 ft) elevation (April–December)',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(primarily)\nP. falciparum(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Albania',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Algeria',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'American Samoa  (US)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Andorra',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Angola',
#   'Entry Requirements': 'Required for arriving travelers ≥9 months old',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Anguilla (U.K.)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Antarctica',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Antigua and Barbuda',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Argentina',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': 'Recommended: for travelers ≥9 months old going to Corrientes and Misiones Provinces.\nGenerally not recommended: for travel to Formosa Province or to designated areas of Chaco, Jujuy, and Salta Provinces.\nNot recommended: for travel limited to provinces and areas not listed above.',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Armenia',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Aruba',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1Entry will be denied if a valid vaccination certificate cannot be provided.',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Australia',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1Travelers arriving from the Galápagos Islands of Ecuador are exempt from this requirement.',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Austria',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Azerbaijan',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Azores (Portugal)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bahamas, The',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bahrain',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bangladesh',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Districts of Chittagong Hill Tract (Bandarban, Khagrachari, and Rangamati); and the following districts: Chattogram (Chittagong) and Cox’s Bazar (in Chattogram [Chittagong] Division); Mymensingh, Netrakona, and Sherpur (in Mymensingh Division); Kurigram (in Rangpur Division); Habiganj, Moulvibazar, Sunamganj, and Sylhet (in Sylhet Division)\nNo malaria transmission in Dhaka (the capital)',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(80%)\nP. vivax(20%)\nP. malariae(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Barbados',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission.1Travelers arriving from Guyana or Trinidad & Tobago are exempt from this requirement, unless an outbreak is occurring.',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Belarus',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Belgium',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Belize',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Benin',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale,andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bermuda (U.K.)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bhutan',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Rare cases in rural areas <1,700 m (≈5,500 ft) elevation in districts along the southern border shared with India',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(primarily)\nP. falciparum(less commonly)',
#   'Recommended Chemoprophylaxis': 'None (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bolivia',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Recommended: for travelers ≥9 months old going to areas <2,300 m (≈7,550 ft) elevation, east of the Andes Mountains: the entire departments of Beni, Pando, Santa Cruz, and designated areas in the departments of Chuquisaca, Cochabamba, La Paz, and Tarija.\nNot recommended: for travel limited to areas >2,300 m (≈7,550 ft) elevation and any areas not listed above, including the cities of La Paz (administrative capital) and Sucre (constitutional [legislative and judicial] capital).',
#   'Transmission Areas': 'All areas <2,500 m (≈8,200 ft) elevation\nNo malaria transmission in La Paz (administrative capital)',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(99%)\nP. falciparum(1%)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, primaquine5,\xa0tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bonaire',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bosnia and Herzegovina',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Botswana',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes transits through countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Districts/ subdistricts of Bobirwa, Boteti, Chobe (including Chobe National Park), Ghanzi, Mahalapye, Ngamiland (Ngami), North East (including its capital, Francistown), Okavango, Serowe/ Palapye, and Tutume\nRare cases or sporadic foci of transmission in districts/ subdistricts of Kgalagadi North, Kgatleng, Kweneng, and Southern\nNo malaria transmission in Gaborone (the capital)',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Districts/subdistricts of Bobirwa, Boteti, Chobe (including Chobe National Park), Ghanzi, Mahalapye, Ngamiland (Ngami), North-East (including its capital, Francistown), Okavango, Serowe/Palapye, and Tutume: Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3\nAreas with rare cases or sporadic foci of transmission: no chemoprophylaxis recommended (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Brazil',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': 'Recommended: for travelers ≥9 months old going to the states of Acre, Amapá, Amazonas, Distrito Federal (including the capital city, Brasília), Espírito Santo,* Goiás, Maranhão, Mato Grosso, Mato Grosso do Sul, Minas Gerais, Pará, Paraná,* Piauí, Rio de Janeiro (including the city of Rio de Janeiro and all coastal islands),* Rio Grande do Sul,* Rondônia, Roraima, Santa Catarina,* São Paulo (including the city of São Paulo and all coastal islands),* Tocantins, and designated areas of Bahia*. Vaccination is also recommended for travelers going to Iguaçu Falls.\nNot recommended: for travel limited to any areas not listed above, including the cities of Fortaleza and Recife *In 2017, in response to a large YF outbreak in multiple eastern states, CDC expanded its vaccination recommendations for travelers going to Brazil. The expanded YF vaccination recommendations for these states are preliminary. For updates, refer to the CDC Travelers’ Health website.',
#   'Transmission Areas': 'All areas in the states of Acre, Amapá, Amazonas, Rondônia, and Roraima\nPresent in the states of Maranhão, Mato Grosso, and Pará, but rare cases in their capital cities (São Luis [capital of Maranhão], Cuiabá [capital of Mato Grosso], Belém [capital of Pará])\nRare cases and sporadic foci of transmission in rural and forested areas in the states of Espírito Santo, Goiás, Minas Gerais, Mato Grosso do Sul, Piauí, Rio de Janeiro, São Paolo, and Tocantins\nNo malaria transmission in the cities of Brasília (the capital), Rio de Janeiro, or São Paolo\nNo malaria transmission at Iguaçu Falls',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(90%)\nP. falciparum(10%)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3\nAreas with rare cases: No chemoprophylaxis recommended (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'British Indian Ocean Territory; includes Diego Garcia (U.K.)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Brunei',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'No human malaria\nRare transmission ofP. knowlesi6in primarily forested or forest-fringe areas',
#   'Drug Resistance': 'None',
#   'Species': 'P. knowlesi6(100%)',
#   'Recommended Chemoprophylaxis': 'None (insect bite precautions and\xa0mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Bulgaria',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Burkina Faso',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Burma (Myanmar)',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'All areas',
#   'Drug Resistance': 'Chloroquine and mefloquine',
#   'Species': 'P. vivax(80%)\nP. falciparum(20%)\nP. knowlesi6,P. malariae, andP. ovale(rare)',
#   'Recommended Chemoprophylaxis': 'Areas in the regions of Bago and Tanintharyi; and in the states of Kachin, Kayah, Kayin, and Shan: Atovaquone-proguanil, doxycycline, tafenoquine3\nAll other areas: Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Burundi',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Cambodia',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Primarily isolated to pockets in rural and forested areas\nRare cases in non-forested areas\nNo (or negligible) malaria transmission in the cities of Phnom Penh (the capital) and Siem Reap\nNo (or negligible) malaria transmission at the main temple complex at Angkor Wat',
#   'Drug Resistance': 'Chloroquine and mefloquine',
#   'Species': 'P. vivax(95%)\nP. falciparum(5%)\nP. malariaeandP. knowlesi6(rare)',
#   'Recommended Chemoprophylaxis': 'Rural and forested areas: Atovaquone-proguanil, doxycycline, primaquine5, tafenoquine3\nAreas with rare cases: No chemoprophylaxis recommended (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Cameroon',
#   'Entry Requirements': 'Required for all arriving travelers ≥1 year old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Canada',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Canary Islands ( Spain )',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Cape Verde',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Cayman Islands (U.K.)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Central African Republic',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old .',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Chad',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Recommended: for travelers ≥9 months old going to areas south of the Sahara Desert.\nNot recommended: for travel limited to areas in the Sahara Desert.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Chile',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'China',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1Travelers with itineraries limited to Hong Kong Special Administrative Region (SAR) or Macao SAR are exempt from this requirement.',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Christmas Island (Australia)',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1Travelers arriving from the Galápagos Islands of Ecuador are exempt from this requirement.',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Cocos (Keeling) Islands (Australia)',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1Travelers arriving from the Galápagos Islands of Ecuador are exempt from this requirement.',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Colombia',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from Angola, Brazil, Democratic Republic of the Congo, or Uganda; this includes >12-hour airport transits or layovers in any of these countries.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old except as follows.\nGenerally not recommended: for travel limited to the cities of Barranquilla, Cali, Cartagena, or Medellín.\nNot recommended: for travel limited to areas >2,300 m (≈7,550 ft) elevation, the archipelago department of San Andrés and Providencia, or the city of Bogotá (the capital).',
#   'Transmission Areas': 'All areas <1,700 m (≈5,600 ft) elevation\nNo malaria transmission in the cities of Bogotá (the capital), Cartagena, or Medellín',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(50%)\nP. vivax(50%)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Comoros',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariaeandP. vivax(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Congo, Republic of the (Congo-Brazzaville)',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Cook Islands (New Zealand)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Costa Rica',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission.1Included in this requirement are travelers arriving from Tanzania and Zambia, and designated areas of: Colombia (the entire country, except the cities of Barranquilla, Bogotá, Cali, Cartagena, and Medellín, and the archipelago department, San Andrés and Providencia); Ecuador (the provinces of Morona-Santiago, Napo, Orellana, Pastaza, Sucumbíos, and Zamora-Chinchipe, and excluding the rest of the country); Paraguay (the entire country, except the city of Asunción); Peru (the entire country, except the cities of Cusco and Lima, the regions of Cajamarca, Lambayeque, Piura, and Tumbes, and the highland tourist areas of Machu Picchu and the Inca Trail); Trinidad & Tobago (the entire country, except the urban areas of Port of Spain; travelers with itineraries limited to the island of Tobago, and travelers with airport transits or layovers are also exempt from this requirement). Travelers arriving from Argentina and Panama are exempt from this requirement.',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Present in the provinces of Alajuela and Limón\nRare to no transmission in other parts of the country',
#   'Drug Resistance': 'None',
#   'Species': 'P. falciparum(86%)\nP. vivax(14%)',
#   'Recommended Chemoprophylaxis': 'Alajuela and Limón Provinces: Atovaquone-proguanil, chloroquine, doxycycline, mefloquine, tafenoquine3\nAll other areas: None (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': "Côte d'Ivoire (Ivory Coast)",
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Croatia',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Cuba',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Curaçao, Netherlands',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': ''},
#  {'Country': 'Cyprus',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Czechia',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Democratic Republic of the Congo (Congo-Kinshasa)',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Denmark',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Djibouti',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(60–70%)\nP. vivax(30–40%)\nP. ovale(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Dominica',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Dominican Republic',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from the following states in Brazil: Espírito Santo, Mina Gerais, Rio de Janeiro, São Paulo; this includes >12-hour airport transits or layovers in any of these states',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Primarily in the provinces (including resort areas) of Azua, Elias Piña, La Altagracia, San Juan, and Santo Domingo\nIn the Distrito Nacional, city of Santo Domingo (the capital), primarily in the La Ciénaga and Los Tres Brazos areas\nRare transmission in other provinces',
#   'Drug Resistance': 'None',
#   'Species': 'P. falciparum(100%)',
#   'Recommended Chemoprophylaxis': 'Provinces (including resort areas) of Azua, Elias Piña, La Altagracia, San Juan, and Santo Domingo: Atovaquone-proguanil, chloroquine, doxycycline, mefloquine, tafenoquine3\nAll other areas: No chemoprophylaxis recommended (insect bite precautions and\xa0mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Easter Island (Chile)',
#   'Entry Requirements': 'Easter Island has not stated its YF vaccination certificate requirements',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Ecuador, including the Galápagos Islands',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from Brazil, Democratic Republic of the Congo, or Uganda; this includes >12-hour airport transits or layovers in any of these countries .',
#   'CDC Recommendations': 'Recommended: for travelers ≥9 months old going to areas <2,300 m (≈7,550 ft) elevation, east of the Andes Mountains, in the provinces of Morona-Santiago, Napo, Orellana, Pastaza, Sucumbíos, Tungurahua,* and Zamora-Chinchipe.\nGenerally not recommended: for travel limited to areas <2,300 m (≈7,550 ft) elevation, west of the Andes Mountains, in the provinces of Esmeraldas,* Guayas, Los Ríos, Manabí, Santa Elena, Santo Domingo de los Tsáchilas, and designated areas in the provinces of Azuay, Bolívar, Cañar, Carchi, Chimborazo, Cotopaxi, El Oro, Imbabura, Loja, and Pichincha.\nNot recommended: for travel limited to areas >2,300 m (≈7,550 ft) elevation, the cities of Guayaquil or Quito (the capital), or the Galápagos Islands *CDC recommendations differ from those published by WHO .',
#   'Transmission Areas': 'Areas <1,500 m (<5,000 ft) elevation in the provinces of Cotopaxi, Esmeraldas, Morona-Santiago, Orellana, Pastaza, and Sucumbíos\nRare cases <1,500 m (<5,000 ft) in all other provinces\nNo malaria transmission in the cities of Guayaquil or Quito (the capital)\nNo malaria transmission on the Galápagos Islands',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(85%)\nP. falciparum(15%)',
#   'Recommended Chemoprophylaxis': 'Transmission areas in the provinces of Cotopaxi, Esmeraldas, Morona-Santiago, Orellana, Pastaza, and Sucumbíos: Atovaquone-proguanil, doxycycline, mefloquine,\xa0tafenoquine3\nAll other areas with reported malaria transmission: No chemoprophylaxis recommended (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Egypt',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'El Salvador',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Equatorial Guinea',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae, P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Eritrea',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Generally not recommended: for travel to the regions of: Anseba, Debub (also known as South or Southern Region), Gash Barka, Ma’ekel (also known as Ma’akel or Central Region), or Semenawi K’eyih Bahri (also known as Northern Red Sea Region).\nNot recommended: for travel to any areas not listed above, including the Dahlak Archipelago.',
#   'Transmission Areas': 'All areas <2,200 m (≈7,200 ft) elevation\nNo malaria transmission in Asmara (the capital)',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(80–85%)\nP. vivax(15–20%)\nP. malariaeandP. ovale(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Estonia',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Eswatini (Swaziland)',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Eastern areas bordering Mozambique and South Africa, including the entire region of Lubombo and the eastern half of Hhohho, Manzini, and Shiselweni Regions',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale,\xa0andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Ethiopia',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old except as follows.\nGenerally not recommended: for travel limited to the regions of Afar or Somali.',
#   'Transmission Areas': 'All areas <2,500 m (<8,200 ft) elevation',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(70%)\nP.\xa0vivax(30%)\nP. malariaeandP. ovale(rare)',
#   'Recommended Chemoprophylaxis': 'All areas <2,500m (8,200 ft) elevation: Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'January 17, 2025'},
#  {'Country': 'Falkland Islands (Islas Malvinas), UK Overseas Territory (also claimed by Argentina)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Faroe Islands (Denmark)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Fiji',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Finland',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'France',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'French Guiana',
#   'Entry Requirements': 'Required for all arriving travelers ≥1 year old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'Areas associated with gold mining, primarily the communes near the border with Brazil and Suriname, especially Régina and Saint-Georges-de-l’Oyapock; also, the communes of Kourou, Matoury, and Saint-Élie\nNo malaria transmission in coastal areas west of Kourou\nNo malaria transmission in Cayenne City (the capital)',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(85%)\nP. falciparum(15%)\nP. malariae(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'French Polynesia, including the Society Islands [Bora-Bora, Moorea & Tahiti]; Marquesas Islands [Hiva Oa & Ua Huka]; and Austral Islands (Tubuai & Rurutu), France',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Gabon',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Gambia, The',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Georgia',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Germany',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Ghana',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale,andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Gibraltar (U.K.)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Greece',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Rare, local transmission in agricultural areas, associated with imported malaria (May–November)\nNo malaria transmission in tourist\u202fareas',
#   'Drug Resistance': 'Not applicable',
#   'Species': 'P. vivax(100%)',
#   'Recommended Chemoprophylaxis': 'None',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Greenland (Denmark)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Grenada',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Guadeloupe (including Marie-Galante, La Désirade & Îles des Saintes)',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Guam (U.S.)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Guatemala',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Primarily in the departments of Alta Verapaz, Baja Verapaz, Escuintla, Izabal, and Petén\nFew cases reported in other departments\nNo malaria transmission in the cities of Antigua\xa0or Guatemala City\xa0(the capital)\nNo malaria transmission at Lake Atitlán',
#   'Drug Resistance': 'None',
#   'Species': 'P. vivax(99%)\nP. falciparum(1%)',
#   'Recommended Chemoprophylaxis': 'Departments of Alta Verapaz, Baja Verapaz, Escuintla, Izabal, and Petén: Atovaquone-proguanil, chloroquine, doxycycline, mefloquine, primaquine5, tafenoquine3\nOther areas with reported malaria transmission: No chemoprophylaxis recommended (insect bite precautions and\xa0mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Guinea',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission.1Required for all arriving travelers from all countries if traveler is ≥9 months of age and arriving at Ahmed Sékou Touré International Airport in Conakry.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Guinea-Bissau',
#   'Entry Requirements': 'Required for all arriving travelers ≥1 year old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Guyana',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >4-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All\nRare cases in the cities of Georgetown (the capital) and New Amsterdam',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(60%)\nP. falciparum(40%)',
#   'Recommended Chemoprophylaxis': 'All areas (except the cities of Georgetown and New Amsterdam): Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3\nCities of Georgetown and Amsterdam:\xa0No chemoprophylaxis recommended (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Haiti',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'All (including Labadee, also known as Port Labadee)',
#   'Drug Resistance': 'None',
#   'Species': 'P. falciparum(99%)\nP. malariae(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, chloroquine, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Honduras',
# ...
#   'Drug Resistance': 'None',
#   'Species': 'P. vivax(100%)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, chloroquine, doxycycline, mefloquine, primaquine5, or tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'South Sudan',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Spain',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Sri Lanka',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Sudan',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': 'Recommended: for travelers ≥9 months old going to areas south of the Sahara Desert.\nNot recommended: for travel limited to areas in the Sahara Desert or the city of Khartoum (the capital).',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(90%)\nP. vivax(5–10%)\nP. malariaeandP. ovale(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Suriname',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'No indigenous cases since 2021\nPreviously, primarily in Sipaliwini District, near the border with French Guiana, with limited transmission in Brokopondo, Marowijne, and Para\xa0(near the border with French Guiana)',
#   'Drug Resistance': 'Previously, chloroquine',
#   'Species': 'Previously,P. vivax(primarily)\nPreviously,P. falciparum(rare)',
#   'Recommended Chemoprophylaxis': 'None\xa0(insect bite precautions and\xa0mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Sweden',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Switzerland',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Syria',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Taiwan',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Tajikistan',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Tanzania',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Generally not recommended: for travel to Tanzania.',
#   'Transmission Areas': 'All areas below 1,800 m (≈5,900\u202fft) elevation',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariaeandP. ovale(less commonly)\nP. vivax(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Thailand',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Primarily\xa0the provinces that border Burma (Myanmar), Cambodia (rare cases in Buri Ram Province), and Malaysia (especially in the rural forest and forest-fringe areas of these provinces)\nRare to few cases in other parts of Thailand, including the cities of Bangkok (the capital), Chiang Mai, and Chiang Rai, or on the islands of Koh Pha Ngan, Koh Samui, or Phuket\nNo malaria transmission on the islands of Krabi Province (Koh Lanta, Koh Phi Phi, Koh Yao Noi, Koh Yao Yai) or in Pattaya City',
#   'Drug Resistance': 'Chloroquine and mefloquine',
#   'Species': 'P. vivax(80%)\nP. falciparum(<20%)\nP. knowlesi6,P. malariae, andP. ovale(rare)',
#   'Recommended Chemoprophylaxis': 'Provinces that border Burma (Myanmar), Cambodia (except Buri Ram Province), and Malaysia: Atovaquone-proguanil, doxycycline, tafenoquine3\nAll other areas with malaria transmission (including Buri Ram province): No chemoprophylaxis recommended (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Timor-Leste',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Rare cases; outbreak in Indonesia border area in 2020',
#   'Drug Resistance': 'Previously, chloroquine',
#   'Species': 'Previously,P. falciparum(50%)\nPreviously,P. vivax(50%)\nPreviously,P. malariaeandP. ovale(each <1%)',
#   'Recommended Chemoprophylaxis': 'None (insect bite precautions and\xa0mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Togo',
#   'Entry Requirements': 'Required for all arriving travelers ≥9 months old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Tokelau (New Zealand)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Tonga',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Trinidad and Tobago',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': 'Recommended: for travelers ≥9 months old going to densely forested areas on Trinidad.\nNot recommended: for cruise ship passengers, airplane passengers in transit, or travel limited to Tobago.',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Tunisia',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Türkiye (Turkey)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Turkmenistan',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Turks and Caicos Islands (U.K.)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Tuvalu',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Uganda',
#   'Entry Requirements': 'Required for all arriving travelers ≥1 year old.',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Ukraine',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'United Arab Emirates',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'United Kingdom (including Channel Islands, Isle of Man, Ascension Island & Tristan Da Cunha Archipelago)',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'United States of America',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Uruguay',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Uzbekistan',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Vanuatu',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(primarily)\nP. falciparumandP. ovale(rare)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Venezuela',
#   'Entry Requirements': 'Required for travelers ≥1 year old arriving from Brazil; this includes >12-hour airport transits or layovers in Brazil',
#   'CDC Recommendations': 'Recommended: for all travelers ≥9 months old except as follows.\nGenerally not recommended: for travel limited to the Distrito Capital or the states of Aragua, Carabobo, Miranda, Vargas, or Yaracuy.\nNot recommended: for travel limited to areas >2,300m (≈7,550 ft) elevation in the states of Mérida, Táchira, or Trujillo; the states of Falcón or Lara; Margarita Island; or the cities of Caracas (the capital) or Valencia .',
#   'Transmission Areas': 'All areas <1,700 m (≈5,600 ft) elevation and Angel Falls',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. vivax(75%)\nP. falciparum(25%)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Vietnam',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'Rural areas only; rare cases in the Mekong and Red River Deltas\nNone in the cities of Da Nang, Hai Phong, Hanoi, Ho Chi Minh City (Saigon), Nha Trang, and Quy Nhon',
#   'Drug Resistance': 'Chloroquine and mefloquine',
#   'Species': 'P. vivax(55%)\nP. falciparum(44%)\nP. knowlesi6,P. malariae, andP. ovale(rare)',
#   'Recommended Chemoprophylaxis': 'Provinces of Bình Dương, Bình Phước, Đắk Lắk, Đắk Nông, Gia Lai, Khánh Hòa, Kon Tum, Lâm Đồng, Ninh Thuận, Tây Ninh: Atovaquone-proguanil, doxycycline, tafenoquine3\nAll other areas with malaria transmission (except Mekong and Red River Deltas): Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3\nMekong and Red River Deltas: No chemoprophylaxis recommended (insect bite precautions and mosquito avoidance only)4',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Virgin Islands, British',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Virgin Islands, U.S.',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Wake Island, U.S.',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': '',
#   'Drug Resistance': '',
#   'Species': '',
#   'Recommended Chemoprophylaxis': '',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Yemen',
#   'Entry Requirements': 'None',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'All areas <2,000 m (≈6,500 ft) elevation\nNo malaria transmission in Sana’a (the capital)',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Zambia',
#   'Entry Requirements': 'Required for travelers ≥1 year of age arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': 'Generally not recommended: for travel to North-Western Province or Western Province.\nNot recommended: for travel to any areas not listed above.',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'},
#  {'Country': 'Zimbabwe',
#   'Entry Requirements': 'Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1',
#   'CDC Recommendations': '',
#   'Transmission Areas': 'All',
#   'Drug Resistance': 'Chloroquine',
#   'Species': 'P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)',
#   'Recommended Chemoprophylaxis': 'Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3',
#   'Last Updated': 'October 4, 2024'}]

# %%
df
# Out:
#                   Country                                 Entry Requirements  \
# 0             Afghanistan                                               None
# 1                 Albania  Required for travelers ≥1 year old arriving fr...
# 2                 Algeria  Required for travelers ≥9 months old arriving ...
# 3    American Samoa  (US)                                               None
# 4                 Andorra                                               None
# ..                    ...                                                ...
# 240  Virgin Islands, U.S.                                               None
# 241     Wake Island, U.S.                                               None
# 242                 Yemen                                               None
# 243                Zambia  Required for travelers ≥1 year of age arriving...
# 244              Zimbabwe  Required for travelers ≥9 months old arriving ...
#
#                                    CDC Recommendations  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 240
# 241
# 242
# 243  Generally not recommended: for travel to North...
# 244
#
#                                     Transmission Areas Drug Resistance  \
# 0    All areas <2,500 m (≈8,200 ft) elevation (Apri...     Chloroquine
# 1
# 2
# 3
# 4
# ..                                                 ...             ...
# 240
# 241
# 242  All areas <2,000 m (≈6,500 ft) elevation\nNo m...     Chloroquine
# 243                                                All     Chloroquine
# 244                                                All     Chloroquine
#
#                                                Species  \
# 0    P. vivax(primarily)\nP. falciparum(less commonly)
# 1
# 2
# 3
# 4
# ..                                                 ...
# 240
# 241
# 242  P. falciparum(primarily)\nP. malariae,P. ovale...
# 243  P. falciparum(primarily)\nP. malariae,P. ovale...
# 244  P. falciparum(primarily)\nP. malariae,P. ovale...
#
#                           Recommended Chemoprophylaxis     Last Updated
# 0    Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
# 1                                                       October 4, 2024
# 2                                                       October 4, 2024
# 3                                                       October 4, 2024
# 4                                                       October 4, 2024
# ..                                                 ...              ...
# 240                                                     October 4, 2024
# 241                                                     October 4, 2024
# 242  Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
# 243  Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
# 244  Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
#
# [245 rows x 8 columns]

# %%
import plotly.express as px

# Identify Chloroquine & Mefloquine resistance cases
df["CQ_resist"] = df["Drug Resistance"].str.contains("Chloroquine", na=False)
df["MQ_resist"] = df["Drug Resistance"].str.contains("mefloquine", na=False)

# Assign resistance types (Include CQ, MQ, both resistant cases, and No Resistance)
df["Resistance Type"] = ""
df.loc[df["CQ_resist"], "Resistance Type"] = "CQ-resist"
df.loc[df["MQ_resist"], "Resistance Type"] = "MQ-resist"
df.loc[df["CQ_resist"] & df["MQ_resist"], "Resistance Type"] = "CQ & MQ resist"

# Identify countries with No malaria transmission
df.loc[(df["Transmission Areas"] == ""), "Resistance Type"] = "No Malaria"

# Identify countries with malaria transmission but no recorded resistance
df.loc[(df["Transmission Areas"].notna()) & 
       (df["Transmission Areas"] != "") & 
       (df["Drug Resistance"] == ""), "Resistance Type"] = "No Resistance"

# Filter out only the relevant cases
df_filtered = df[df["Resistance Type"].notna()].copy()

# Define readable categories for visualization
resistance_map = {
    "CQ-resist": "Chloroquine-resistant",
    "MQ-resist": "Mefloquine-resistant",
    "CQ & MQ resist": "Chloroquine & Mefloquine resistant",
    "No Resistance": "No Recorded Resistance"
}
df_filtered["Resistance Category"] = df_filtered["Resistance Type"].map(resistance_map)

# Define color mapping for better visualization
color_scheme = {
    "Chloroquine-resistant": "red",
    "Mefloquine-resistant": "green",
    "Chloroquine & Mefloquine resistant": "purple",
    "No Recorded Resistance": "blue"
}

# Create an interactive map with species information in hover tooltip
fig = px.choropleth(
    df_filtered,
    locations="Country",
    locationmode="country names",
    color="Resistance Category",
    title="Global Distribution of Malaria Drug Resistance",
    color_discrete_map=color_scheme,
    hover_data={"Country": True, "Species": True}  # Show species in tooltip
)

# Show the interactive map
fig.show()

# %%
# Function to categorize Yellow Fever Entry Requirements
def categorize_entry_requirements(text):
    if pd.isna(text) or text.strip().lower() in ["none", "no requirements", "not required", ""]:
        return "None"
    elif re.search(r"arriving\s*from\s*countries\s*with\s*risk\s*for\s*YF\s*virus\s*transmission", text, re.IGNORECASE):
        return "Arriving from countries with risk for YF virus transmission"
    elif re.search(r"required\s*for\s*(all\s*)?arriving\s*travelers", text, re.IGNORECASE):
        return "Required for all arriving travelers"
    else:
        return "Other"

# Apply categorization to the existing DataFrame
df["Entry Category"] = df["Entry Requirements"].apply(categorize_entry_requirements)

# Display the updated DataFrame
from IPython.display import display
display(df.head(10))
# Out:
#                 Country                                 Entry Requirements  \
# 0           Afghanistan                                               None
# 1               Albania  Required for travelers ≥1 year old arriving fr...
# 2               Algeria  Required for travelers ≥9 months old arriving ...
# 3  American Samoa  (US)                                               None
# 4               Andorra                                               None
# 5                Angola      Required for arriving travelers ≥9 months old
# 6       Anguilla (U.K.)                                               None
# 7            Antarctica                                               None
# 8   Antigua and Barbuda  Required for travelers ≥1 year old arriving fr...
# 9             Argentina                                               None
#
#                                  CDC Recommendations  \
# 0
# 1
# 2
# 3
# 4
# 5       Recommended: for all travelers ≥9 months old
# 6
# 7
# 8
# 9  Recommended: for travelers ≥9 months old going...
#
#                                   Transmission Areas Drug Resistance  \
# 0  All areas <2,500 m (≈8,200 ft) elevation (Apri...     Chloroquine
# 1
# 2
# 3
# 4
# 5                                                All     Chloroquine
# 6
# 7
# 8
# 9
#
#                                              Species  \
# 0  P. vivax(primarily)\nP. falciparum(less commonly)
# 1
# 2
# 3
# 4
# 5  P. falciparum(primarily)\nP. malariae,P. ovale...
# 6
# 7
# 8
# 9
#
#                         Recommended Chemoprophylaxis     Last Updated  \
# 0  Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
# 1                                                     October 4, 2024
# 2                                                     October 4, 2024
# 3                                                     October 4, 2024
# 4                                                     October 4, 2024
# 5  Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
# 6                                                     October 4, 2024
# 7                                                     October 4, 2024
# 8                                                     October 4, 2024
# 9                                                     October 4, 2024
#
#    CQ_resist  MQ_resist Resistance Type  \
# 0       True      False       CQ-resist
# 1      False      False      No Malaria
# 2      False      False      No Malaria
# 3      False      False      No Malaria
# 4      False      False      No Malaria
# 5       True      False       CQ-resist
# 6      False      False      No Malaria
# 7      False      False      No Malaria
# 8      False      False      No Malaria
# 9      False      False      No Malaria
#
#                                       Entry Category
# 0                                               None
# 1  Arriving from countries with risk for YF virus...
# 2  Arriving from countries with risk for YF virus...
# 3                                               None
# 4                                               None
# 5                Required for all arriving travelers
# 6                                               None
# 7                                               None
# 8  Arriving from countries with risk for YF virus...
# 9                                               None

# %%
# # Save to CSV
# df.to_csv("yellow_fever_malaria_data_cleaned_yfcat.csv", index=False)

# %%
# # Export the final DataFrame to an Excel file
# df.to_excel("yellow_fever_malaria_data_cleaned_yfcat.xlsx", index=False)

# %%
# Define dictionary to map unrecognized territories to recognized countries

tableau_mapping = {
    "Azores (Portugal)": "Azores",
    "British Indian Ocean Territory; includes Diego Garcia (U.K.)": "British Indian Ocean Territory",
    "Canary Islands ( Spain )": "Canary Islands",
    "Christmas Island (Australia)": "Christmas Island",
    "Cocos (Keeling) Islands (Australia)": "Cocos (Keeling) Islands",
    "Cook Islands (New Zealand)": "Cook Islands",
    "Curaçao, Netherlands": "Curaçao",
    "Congo, Republic of the (Congo-Brazzaville)": "Republic of Congo",
    "Democratic Republic of the Congo (Congo-Kinshasa)": "Democratic Republic of Congo",
    "Easter Island (Chile)": "Easter Island",
    "Ecuador, including the Galápagos Islands": "Ecuador",
    "Eswatini (Swaziland)": "Eswatini",
    "Falkland Islands (Islas Malvinas), UK Overseas Territory (also claimed by Argentina)": "Falkland Islands (Islas Malvinas)",
    "Faroe Islands (Denmark)": "Faroe Islands",
    "French Polynesia, including the Society Islands [Bora-Bora, Moorea & Tahiti]; Marquesas Islands [Hiva Oa & Ua Huka]; and Austral Islands (Tubuai & Rurutu), France": "French Polynesia",
    "Gibraltar (U.K.)": "Gibraltar",
    "Greenland (Denmark)": "Greenland",
    "Guadeloupe (including Marie-Galante, La Désirade & Îles des Saintes)": "Guadeloupe",
    "Italy (including Holy See [Vatican City])" : "Italy",
    "Kiribati (formerly Gilbert Islands), includes Tarawa, Tabuaeran (Fanning Island), and Banaba (Ocean Island)": "Kiribati",
    "Macau (China)": "Macau",
    "Madeira Islands (Portugal)": "Madeira Islands",
    "Mayotte (France)": "Mayotte",
    "Micronesia, Federated States of (including Chuuk, Kosrae, Pohnpei & Yap)": "Federated States of Micronesia",
    "Montserrat, United Kingdom": "Montserrat",
    "Netherlands Antilles (Bonaire, Curaçao, Saba, St. Eustasius, and St. Maarten)": "Netherlands Antilles",
    "Niue (New Zealand)": "Niue",
    "Norfolk Island (Australia)": "Norfolk Island",
    "Northern Mariana Islands (U.S.), includes Saipan, Tinian, and Rota Island": "Northern Mariana Islands",
    "Saba, Netherlands": "Saba",
    "Saint Barthelemy, France": "Saint Barthelemy",
    "Saint Helena, United Kingdom": "Saint Helena",
    "Saint Kitts (Saint Christopher) & Nevis": "Saint Kitts and Nevis",
    "Saint Martin, France": "Saint Martin",
    "Saint Pierre and Miquelon (France)": "Saint Pierre and Miquelon",
    "Samoa (formerly Western Somoa)": "Samoa",
    "Sint Eustatius, Netherlands": "Sint Eustatius",
    "Sint Maarten, Netherlands": "Sint Maarten (Dutch part)",
    "South Georgia & the South Sandwich Islands, UK Overseas Territory (also claimed by Argentina)": "South Georgia and the South Sandwich Islands",
    "Tokelau (New Zealand)": "Tokelau",
    "Türkiye (Turkey)": "Turkey",
    "Turks and Caicos Islands (U.K.)": "Turks and Caicos Islands",
    "United Kingdom (including Channel Islands, Isle of Man, Ascension Island & Tristan Da Cunha Archipelago)": "United Kingdom",
    "Wake Island, U.S.": "Wake Island"
}

# %%
# Define a function to get the correct country name to match with Tableau data
def get_country_tableau(country_name):
    if country_name not in tableau_mapping:
        return country_name
    mapped_value = tableau_mapping[country_name]
    if mapped_value == "Unrecognized":
        return country_name
    else:
        return mapped_value

# %%
# Create a new column in df_csv
df["Country_Tableau"] = df["Country"].apply(get_country_tableau)

# %%
# Export the final DataFrame to an Excel file
df.to_excel("yellow_fever_malaria_data_cleaned_yfcat_tableau.xlsx", index=False)

# %%
from IPython.display import display, HTML

# Load DataTable for full table display
def render_myscroll_table(df):
    return display(HTML(df.to_html(index=False, classes="display nowrap", escape=False)))

# Show DataFrame
render_myscroll_table(df)
# Out:
# <table border="1" class="dataframe display nowrap">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Country</th>
#       <th>Entry Requirements</th>
#       <th>CDC Recommendations</th>
#       <th>Transmission Areas</th>
#       <th>Drug Resistance</th>
#       <th>Species</th>
#       <th>Recommended Chemoprophylaxis</th>
#       <th>Last Updated</th>
#       <th>CQ_resist</th>
#       <th>MQ_resist</th>
#       <th>Resistance Type</th>
#       <th>Entry Category</th>
#       <th>Country_Tableau</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Afghanistan</td>
#       <td>None</td>
#       <td></td>
#       <td>All areas <2,500 m (≈8,200 ft) elevation (April–December)</td>
#       <td>Chloroquine</td>
#       <td>P. vivax(primarily)\nP. falciparum(less commonly)</td>
#       <td>Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3</td>
#       <td>October 4, 2024</td>
#       <td>True</td>
#       <td>False</td>
#       <td>CQ-resist</td>
#       <td>None</td>
#       <td>Afghanistan</td>
#     </tr>
#     <tr>
#       <td>Albania</td>
#       <td>Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission1</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>Arriving from countries with risk for YF virus transmission</td>
#       <td>Albania</td>
#     </tr>
#     <tr>
#       <td>Algeria</td>
#       <td>Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>Arriving from countries with risk for YF virus transmission</td>
#       <td>Algeria</td>
#     </tr>
#     <tr>
#       <td>American Samoa  (US)</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>American Samoa  (US)</td>
#     </tr>
#     <tr>
#       <td>Andorra</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>Andorra</td>
#     </tr>
#     <tr>
#       <td>Angola</td>
#       <td>Required for arriving travelers ≥9 months old</td>
#       <td>Recommended: for all travelers ≥9 months old</td>
#       <td>All</td>
#       <td>Chloroquine</td>
#       <td>P. falciparum(primarily)\nP. malariae,P. ovale, andP. vivax(less commonly)</td>
#       <td>Atovaquone-proguanil, doxycycline, mefloquine, tafenoquine3</td>
#       <td>October 4, 2024</td>
#       <td>True</td>
#       <td>False</td>
#       <td>CQ-resist</td>
#       <td>Required for all arriving travelers</td>
#       <td>Angola</td>
#     </tr>
#     <tr>
#       <td>Anguilla (U.K.)</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>Anguilla (U.K.)</td>
#     </tr>
#     <tr>
#       <td>Antarctica</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>Antarctica</td>
#     </tr>
#     <tr>
#       <td>Antigua and Barbuda</td>
#       <td>Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>Arriving from countries with risk for YF virus transmission</td>
#       <td>Antigua and Barbuda</td>
#     </tr>
#     <tr>
#       <td>Argentina</td>
#       <td>None</td>
#       <td>Recommended: for travelers ≥9 months old going to Corrientes and Misiones Provinces.\nGenerally not recommended: for travel to Formosa Province or to designated areas of Chaco, Jujuy, and Salta Provinces.\nNot recommended: for travel limited to provinces and areas not listed above.</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>Argentina</td>
#     </tr>
#     <tr>
#       <td>Armenia</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>Armenia</td>
#     </tr>
#     <tr>
#       <td>Aruba</td>
#       <td>Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1Entry will be denied if a valid vaccination certificate cannot be provided.</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>Arriving from countries with risk for YF virus transmission</td>
#       <td>Aruba</td>
#     </tr>
#     <tr>
#       <td>Australia</td>
#       <td>Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1Travelers arriving from the Galápagos Islands of Ecuador are exempt from this requirement.</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>Arriving from countries with risk for YF virus transmission</td>
#       <td>Australia</td>
#     </tr>
#     <tr>
#       <td>Austria</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>Austria</td>
#     </tr>
#     <tr>
#       <td>Azerbaijan</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>Azerbaijan</td>
#     </tr>
#     <tr>
#       <td>Azores (Portugal)</td>
#       <td>None</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>None</td>
#       <td>Azores</td>
#     </tr>
#     <tr>
#       <td>Bahamas, The</td>
#       <td>Required for travelers ≥1 year old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>October 4, 2024</td>
#       <td>False</td>
#       <td>False</td>
#       <td>No Malaria</td>
#       <td>Arriving from countries with risk for YF virus transmission</td>
#       <td>Bahamas, The</td>
#     </tr>
#     <tr>
#       <td>Bahrain</td>
#       <td>Required for travelers ≥9 months old arriving from countries with risk for YF virus transmission; this includes >12-hour airport transits or layovers in countries with risk for YF virus transmission.1</td>
#       <td></td>
