# %%
import pandas as pd

# Load the Excel file
xls = pd.ExcelFile("110m_cultural_all.xlsx")

# The target columns to check in each sheet
target_cols = ['GU_A3', 'SU_A3', 'BRK_A3', 'ADM0_TLC']

# Dictionary to store the matching columns for each sheet
sheet_info = {}

# Loop over each sheet and identify which target columns are present
for sheet in xls.sheet_names:
    df_sheet = pd.read_excel(xls, sheet_name=sheet)
    cols_found = [col for col in df_sheet.columns if col in target_cols]
    sheet_info[sheet] = cols_found

# Create a DataFrame summarizing the results
summary_df = pd.DataFrame(list(sheet_info.items()), columns=["Sheet", "Matching Columns"])
print(summary_df)
# Out:
#                               Sheet                  Matching Columns
# 0         ne_110m_admin_0_countries  [GU_A3, SU_A3, BRK_A3, ADM0_TLC]
# 1   ne_110m_admin_0_countries_lakes  [GU_A3, SU_A3, BRK_A3, ADM0_TLC]
# 2          ne_110m_populated_places                                []
# 3   ne_110m_admin_1_states_province                                []
# 4        ne_110m_admin_0_scale_rank                                []
# 5   ne_110m_admin_0_boundary_lines_                          [BRK_A3]
# 6   ne_110m_populated_places_simple                                []
# 7   ne_110m_admin_0_pacific_groupin                                []
# 8         ne_110m_admin_0_map_units  [GU_A3, SU_A3, BRK_A3, ADM0_TLC]
# 9       ne_110m_admin_0_sovereignty  [GU_A3, SU_A3, BRK_A3, ADM0_TLC]
# 10   ne_110m_admin_0_tiny_countries  [GU_A3, SU_A3, BRK_A3, ADM0_TLC]

# %%
import pandas as pd
import re
from fuzzywuzzy import process
import pycountry
import pycountry_convert as pc

# Updated cleaning function:
def clean_country_name(name):
    if pd.isna(name):
        return ""
    if not isinstance(name, str):
        name = str(name)
    name = name.lower()
    # Special handling: if "french polynesia" appears anywhere, return exactly "french polynesia"
    if "french polynesia" in name:
        return "french polynesia"
    # Remove content within parentheses and trailing ", france" if present
    name = re.sub(r"\(.*?\)", "", name)
    name = re.sub(r",\s*france$", "", name)
    # Normalize whitespace and trim
    name = re.sub(r"\s+", " ", name).strip()
    # Fix common encoding issues
    name = name.replace("c√¥te", "côte")
    name = name.replace("cura√ßao", "curaçao")
    name = name.replace("gal√°pagos", "galápagos")
    name = name.replace("r√©union", "réunion")
    name = name.replace("s√£o", "são")
    name = name.replace("t√ºrkiye", "türkiye")
    return name

# Load your Excel file as DataFrame 'df'
df = pd.read_excel("yellow_fever_malaria_data_cleaned_yfcat_tableau.xlsx")

# Create a cleaned country column based on 'Country_Tableau'
df["Country_clean"] = df["Country_Tableau"].apply(clean_country_name)

# Manual mapping for problematic names (keys are cleaned names).
# For those that should not match, we map them to None.
manual_mapping = {
    "american samoa": "american samoa",
    "anguilla": "anguilla",
    "aruba": "aruba",
    "bonaire": "bonaire",
    "cayman islands": "cayman islands",
    "christmas island": "christmas island",
    "cocos (keeling) islands": None,      # Force no match
    "easter island": None,                # Force no match
    "curaçao, netherlands": "curaçao",
    "french polynesia, including the society islands [bora-bora, moorea & tahiti]; marquesas islands": "french polynesia",
    "gibraltar (u.k.)": "gibraltar",
    "guadeloupe (including marie-galante, la désirade & îles des saintes)": "guadeloupe",
    "macau": "macau (china)",              # Map Macau correctly
    "macau (china)": "macau (china)",
    "madeira islands": "madeira islands (portugal)",  # Map Madeira Islands correctly
    "martinique": "martinique",
    "mayotte (france)": "mayotte",
    "montserrat, united kingdom": "montserrat",
    "netherlands antilles": "netherlands antilles",  # Explicit mapping
    "netherlands antilles (bonaire, curaçao, saba, st. eustasius, and st. maarten)": "netherlands antilles",
    "niue (new zealand)": "niue",
    "norfolk island (australia)": "norfolk island",
    "réunion (france)": "réunion",
    "saba, netherlands": "saba",
    "saint barthelemy, france": "saint barthelemy",
    "saint helena, united kingdom": "saint helena",
    "saint martin, france": "saint martin",
    "sint eustatius, netherlands": "sint eustatius",
    "sint maarten, netherlands": "sint maarten",
    "tokelau (new zealand)": "tokelau",
    "virgin islands, british": "virgin islands, british",
    "virgin islands, u.s.": "virgin islands, u.s.",
    "wake island, u.s.": "wake island, u.s."
}

# Build candidate mapping from the Excel file containing geographic codes.
candidate_map = {}
xls = pd.ExcelFile("110m_cultural_all.xlsx")
for sheet in xls.sheet_names:
    df_sheet = pd.read_excel(xls, sheet_name=sheet)
    # Identify columns that contain "NAME" (case-insensitive)
    name_columns = [col for col in df_sheet.columns if "NAME" in col.upper()]
    for col in name_columns:
        for idx, row in df_sheet.iterrows():
            candidate = row[col]
            if pd.isna(candidate):
                continue
            candidate_clean = clean_country_name(candidate)
            # Correct false detection for Saint Martin if detected as "saint-marin"
            if candidate_clean == "saint-marin":
                candidate_clean = "saint martin"
            candidate_info = {
                "GU_A3": row["GU_A3"] if "GU_A3" in df_sheet.columns else None,
                "SU_A3": row["SU_A3"] if "SU_A3" in df_sheet.columns else None,
                "BRK_A3": row["BRK_A3"] if "BRK_A3" in df_sheet.columns else None,
                "ADM0_TLC": row["ADM0_TLC"] if "ADM0_TLC" in df_sheet.columns else None,
                "SOV_A3": row["SOV_A3"] if "SOV_A3" in df_sheet.columns else None,
                "ADM0_A3": row["ADM0_A3"] if "ADM0_A3" in df_sheet.columns else None,
                "ISO_A2": row["ISO_A2"] if "ISO_A2" in df_sheet.columns else None,
                "SUBUNIT": row["SUBUNIT"] if "SUBUNIT" in df_sheet.columns else None,
                "SUBREGION": row["SUBREGION"] if "SUBREGION" in df_sheet.columns else None,
                "CONTINENT": row["CONTINENT"] if "CONTINENT" in df_sheet.columns else None,
                "sheet": sheet,
                "source_column": col,
                "original_candidate": candidate
            }
            # Update mapping: if candidate exists, update missing values.
            if candidate_clean in candidate_map:
                for key in ["SUBUNIT", "SUBREGION", "CONTINENT", "ISO_A2"]:
                    if candidate_map[candidate_clean][key] is None and candidate_info[key] is not None:
                        candidate_map[candidate_clean][key] = candidate_info[key]
            else:
                candidate_map[candidate_clean] = candidate_info

# Set fuzzy matching threshold.
threshold = 70

# Prepare lists for storing matching results.
BRK_A3_list = []
SOV_A3_list = []
ADM0_A3_list = []
ISO_A2_list = []
SUBUNIT_list = []
SUBREGION_list = []
CONTINENT_list = []
match_score_list = []
match_sheet_list = []
match_source_list = []
match_candidate_list = []
pycountry_used = []  # Flag if pycountry fallback was used

print("Matching results per row:")

# Iterate over each row in df using the cleaned 'Country_clean' column.
for idx, row in df.iterrows():
    country_clean = row["Country_clean"]
    original_score = None
    
    # Check if the country is explicitly in manual mapping.
    if country_clean in manual_mapping:
        best_candidate_key = manual_mapping[country_clean]
        if best_candidate_key is None:
            # Force no match for these cases.
            candidate_info = {}
            score = 0
        else:
            candidate_info = candidate_map.get(best_candidate_key, {})
            score = 100  # Perfect match assumed.
            best_match = best_candidate_key
    else:
        best_match, score = process.extractOne(country_clean, list(candidate_map.keys()))
        candidate_info = candidate_map.get(best_match, {})
    
    original_score = score

    # If candidate_info is missing, set score to 0.
    if not candidate_info.get("original_candidate"):
        score = 0

    # Reject match if the candidate is exactly "island".
    if candidate_info.get("original_candidate", "").strip().lower() == "island":
        score = 0

    # If fuzzy score is ≤ 90, try pycountry (with pycountry_convert for continent) as a fallback.
    used_pycountry = False
    if score <= 90:
        try:
            py_results = pycountry.countries.search_fuzzy(country_clean)
            if py_results:
                py_country = py_results[0]
                # Use pycountry_convert to get continent information
                try:
                    alpha2 = py_country.alpha_2  # Needed for continent conversion
                    continent_code = pc.country_alpha2_to_continent_code(alpha2)
                    continent_mapping = {
                        "AF": "Africa",
                        "AN": "Antarctica",
                        "AS": "Asia",
                        "EU": "Europe",
                        "NA": "North America",
                        "OC": "Oceania",
                        "SA": "South America"
                    }
                    continent_name = continent_mapping.get(continent_code, None)
                except Exception as e:
                    continent_name = None
                candidate_info = {
                    "GU_A3": None,
                    "SU_A3": None,
                    "BRK_A3": py_country.alpha_3,  # Using BRK_A3 from pycountry
                    "ADM0_TLC": None,
                    "SOV_A3": None,
                    "ADM0_A3": None,
                    "ISO_A2": py_country.alpha_2,   # Retrieve ISO_A2 here
                    "SUBUNIT": None,
                    "SUBREGION": None,
                    "CONTINENT": continent_name,
                    "sheet": "pycountry",
                    "source_column": "pycountry",
                    "original_candidate": py_country.name
                }
                score = 100
                used_pycountry = True
        except Exception as e:
            pass

    print(f"Excel Country: '{row['Country_Tableau']}' (clean: '{country_clean}')")
    print(f"  -> Best match candidate: '{candidate_info.get('original_candidate')}'")
    print(f"     from sheet: '{candidate_info.get('sheet')}', column: '{candidate_info.get('source_column')}'")
    print(f"  -> Initial fuzzy score: {original_score} | Final score: {score}")
    print(f"  -> Codes: BRK_A3={candidate_info.get('BRK_A3')}, SOV_A3={candidate_info.get('SOV_A3')}, ADM0_A3={candidate_info.get('ADM0_A3')}")
    print(f"  -> Additional: ISO_A2={candidate_info.get('ISO_A2')}, SUBUNIT={candidate_info.get('SUBUNIT')}, SUBREGION={candidate_info.get('SUBREGION')}, CONTINENT={candidate_info.get('CONTINENT')}")
    if used_pycountry:
        print("  -> Fallback using pycountry (and pycountry_convert) was used.\n")
    else:
        print("\n")
    
    # Accept the match if final score meets the threshold; otherwise, set codes to None.
    if score < threshold:
        BRK_A3_list.append(None)
        SOV_A3_list.append(None)
        ADM0_A3_list.append(None)
        ISO_A2_list.append(None)
        SUBUNIT_list.append(None)
        SUBREGION_list.append(None)
        CONTINENT_list.append(None)
    else:
        BRK_A3_list.append(candidate_info.get("BRK_A3"))
        SOV_A3_list.append(candidate_info.get("SOV_A3"))
        ADM0_A3_list.append(candidate_info.get("ADM0_A3"))
        ISO_A2_list.append(candidate_info.get("ISO_A2"))
        SUBUNIT_list.append(candidate_info.get("SUBUNIT"))
        SUBREGION_list.append(candidate_info.get("SUBREGION"))
        CONTINENT_list.append(candidate_info.get("CONTINENT"))
    
    match_score_list.append(score)
    match_sheet_list.append(candidate_info.get("sheet"))
    match_source_list.append(candidate_info.get("source_column"))
    match_candidate_list.append(candidate_info.get("original_candidate"))
    pycountry_used.append(used_pycountry)

# Append matching results to the DataFrame (without '_best' in column names).
df["BRK_A3"] = BRK_A3_list
df["SOV_A3"] = SOV_A3_list
df["ADM0_A3"] = ADM0_A3_list
df["ISO_A2"] = ISO_A2_list
df["SUBUNIT"] = SUBUNIT_list
df["SUBREGION"] = SUBREGION_list
df["CONTINENT"] = CONTINENT_list
df["match_score"] = match_score_list
df["match_sheet"] = match_sheet_list
df["match_source"] = match_source_list
df["match_candidate"] = match_candidate_list
df["pycountry_used"] = pycountry_used

print("\nFinal merged DataFrame head:")
print(df.head())
# Out:
# Matching results per row:
# Excel Country: 'Afghanistan' (clean: 'afghanistan')
#   -> Best match candidate: 'Afghanistan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=AFG, SOV_A3=AFG, ADM0_A3=AFG
#   -> Additional: ISO_A2=AF, SUBUNIT=Afghanistan, SUBREGION=Southern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Albania' (clean: 'albania')
#   -> Best match candidate: 'Albania'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ALB, SOV_A3=ALB, ADM0_A3=ALB
#   -> Additional: ISO_A2=AL, SUBUNIT=Albania, SUBREGION=Southern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Algeria' (clean: 'algeria')
#   -> Best match candidate: 'Algeria'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=DZA, SOV_A3=DZA, ADM0_A3=DZA
#   -> Additional: ISO_A2=DZ, SUBUNIT=Algeria, SUBREGION=Northern Africa, CONTINENT=Africa
#
#
# Excel Country: 'American Samoa  (US)' (clean: 'american samoa')
#   -> Best match candidate: 'American Samoa'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ASM, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=AS, SUBUNIT=None, SUBREGION=None, CONTINENT=Oceania
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Andorra' (clean: 'andorra')
#   -> Best match candidate: 'Andorra'
#      from sheet: 'ne_110m_populated_places', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=AND, ADM0_A3=AND
#   -> Additional: ISO_A2=AD, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Angola' (clean: 'angola')
#   -> Best match candidate: 'Angola'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=AGO, SOV_A3=AGO, ADM0_A3=AGO
#   -> Additional: ISO_A2=AO, SUBUNIT=Angola, SUBREGION=Middle Africa, CONTINENT=Africa
#
#
# Excel Country: 'Anguilla (U.K.)' (clean: 'anguilla')
#   -> Best match candidate: 'Anguilla'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=AIA, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=AI, SUBUNIT=None, SUBREGION=None, CONTINENT=North America
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Antarctica' (clean: 'antarctica')
#   -> Best match candidate: 'Antarctica'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ATA, SOV_A3=ATA, ADM0_A3=ATA
#   -> Additional: ISO_A2=AQ, SUBUNIT=Antarctica, SUBREGION=Antarctica, CONTINENT=Antarctica
#
#
# Excel Country: 'Antigua and Barbuda' (clean: 'antigua and barbuda')
#   -> Best match candidate: 'Antigua and Barbuda'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=ATG, ADM0_A3=ATG
#   -> Additional: ISO_A2=AG, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Argentina' (clean: 'argentina')
#   -> Best match candidate: 'Argentina'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ARG, SOV_A3=ARG, ADM0_A3=ARG
#   -> Additional: ISO_A2=AR, SUBUNIT=Argentina, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Armenia' (clean: 'armenia')
#   -> Best match candidate: 'Armenia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ARM, SOV_A3=ARM, ADM0_A3=ARM
#   -> Additional: ISO_A2=AM, SUBUNIT=Armenia, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Aruba' (clean: 'aruba')
#   -> Best match candidate: 'Aruba'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ABW, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=AW, SUBUNIT=None, SUBREGION=None, CONTINENT=North America
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Australia' (clean: 'australia')
#   -> Best match candidate: 'Australia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=AUS, SOV_A3=AU1, ADM0_A3=AUS
#   -> Additional: ISO_A2=AU, SUBUNIT=Australia, SUBREGION=Australia and New Zealand, CONTINENT=Oceania
#
#
# Excel Country: 'Austria' (clean: 'austria')
#   -> Best match candidate: 'Austria'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=AUT, SOV_A3=AUT, ADM0_A3=AUT
#   -> Additional: ISO_A2=AT, SUBUNIT=Austria, SUBREGION=Western Europe, CONTINENT=Europe
#
#
# Excel Country: 'Azerbaijan' (clean: 'azerbaijan')
#   -> Best match candidate: 'Azerbaijan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=AZE, SOV_A3=AZE, ADM0_A3=AZE
#   -> Additional: ISO_A2=AZ, SUBUNIT=Azerbaijan, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Azores' (clean: 'azores')
#   -> Best match candidate: 'Azores'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=PAZ, SOV_A3=PRT, ADM0_A3=PRT
#   -> Additional: ISO_A2=-99, SUBUNIT=Azores, SUBREGION=Southern Europe, CONTINENT=Seven seas (open ocean)
#
#
# Excel Country: 'Bahamas, The' (clean: 'bahamas, the')
#   -> Best match candidate: 'Bahamas, The'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_CIAWF'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BHS, SOV_A3=BHS, ADM0_A3=BHS
#   -> Additional: ISO_A2=BS, SUBUNIT=The Bahamas, SUBREGION=Caribbean, CONTINENT=North America
#
#
# Excel Country: 'Bahrain' (clean: 'bahrain')
#   -> Best match candidate: 'Bahrain'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=BHR, ADM0_A3=BHR
#   -> Additional: ISO_A2=BH, SUBUNIT=Bahrain, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Bangladesh' (clean: 'bangladesh')
#   -> Best match candidate: 'Bangladesh'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BGD, SOV_A3=BGD, ADM0_A3=BGD
#   -> Additional: ISO_A2=BD, SUBUNIT=Bangladesh, SUBREGION=Southern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Barbados' (clean: 'barbados')
#   -> Best match candidate: 'Barbados'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=BRB, ADM0_A3=BRB
#   -> Additional: ISO_A2=BB, SUBUNIT=Barbados, SUBREGION=Caribbean, CONTINENT=North America
#
#
# Excel Country: 'Belarus' (clean: 'belarus')
#   -> Best match candidate: 'Belarus'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BLR, SOV_A3=BLR, ADM0_A3=BLR
#   -> Additional: ISO_A2=BY, SUBUNIT=Belarus, SUBREGION=Eastern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Belgium' (clean: 'belgium')
#   -> Best match candidate: 'Belgium'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BEL, SOV_A3=BEL, ADM0_A3=BEL
#   -> Additional: ISO_A2=BE, SUBUNIT=Belgium, SUBREGION=Western Europe, CONTINENT=Europe
#
#
# Excel Country: 'Belize' (clean: 'belize')
#   -> Best match candidate: 'Belize'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BLZ, SOV_A3=BLZ, ADM0_A3=BLZ
#   -> Additional: ISO_A2=BZ, SUBUNIT=Belize, SUBREGION=Central America, CONTINENT=North America
#
#
# Excel Country: 'Benin' (clean: 'benin')
#   -> Best match candidate: 'Benin'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BEN, SOV_A3=BEN, ADM0_A3=BEN
#   -> Additional: ISO_A2=BJ, SUBUNIT=Benin, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Bermuda (U.K.)' (clean: 'bermuda')
#   -> Best match candidate: 'Bermuda'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BMU, SOV_A3=GB1, ADM0_A3=BMU
#   -> Additional: ISO_A2=BM, SUBUNIT=Bermuda, SUBREGION=Northern America, CONTINENT=North America
#
#
# Excel Country: 'Bhutan' (clean: 'bhutan')
#   -> Best match candidate: 'Bhutan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BTN, SOV_A3=BTN, ADM0_A3=BTN
#   -> Additional: ISO_A2=BT, SUBUNIT=Bhutan, SUBREGION=Southern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Bolivia' (clean: 'bolivia')
#   -> Best match candidate: 'Bolivia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BOL, SOV_A3=BOL, ADM0_A3=BOL
#   -> Additional: ISO_A2=BO, SUBUNIT=Bolivia, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Bonaire' (clean: 'bonaire')
#   -> Best match candidate: 'Bonaire, Sint Eustatius and Saba'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BES, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=BQ, SUBUNIT=None, SUBREGION=None, CONTINENT=North America
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Bosnia and Herzegovina' (clean: 'bosnia and herzegovina')
#   -> Best match candidate: 'Bosnia and Herzegovina'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BIH, SOV_A3=BIH, ADM0_A3=BIH
#   -> Additional: ISO_A2=BA, SUBUNIT=Bosnia and Herzegovina, SUBREGION=Southern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Botswana' (clean: 'botswana')
#   -> Best match candidate: 'Botswana'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BWA, SOV_A3=BWA, ADM0_A3=BWA
#   -> Additional: ISO_A2=BW, SUBUNIT=Botswana, SUBREGION=Southern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Brazil' (clean: 'brazil')
#   -> Best match candidate: 'Brazil'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BRA, SOV_A3=BRA, ADM0_A3=BRA
#   -> Additional: ISO_A2=BR, SUBUNIT=Brazil, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'British Indian Ocean Territory' (clean: 'british indian ocean territory')
#   -> Best match candidate: 'British Indian Ocean Territory'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=B69, SOV_A3=GB1, ADM0_A3=IOT
#   -> Additional: ISO_A2=IO, SUBUNIT=British Indian Ocean Territory, SUBREGION=Seven seas (open ocean), CONTINENT=Seven seas (open ocean)
#
#
# Excel Country: 'Brunei' (clean: 'brunei')
#   -> Best match candidate: 'Brunei'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BRN, SOV_A3=BRN, ADM0_A3=BRN
#   -> Additional: ISO_A2=BN, SUBUNIT=Brunei, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Bulgaria' (clean: 'bulgaria')
#   -> Best match candidate: 'Bulgaria'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BGR, SOV_A3=BGR, ADM0_A3=BGR
#   -> Additional: ISO_A2=BG, SUBUNIT=Bulgaria, SUBREGION=Eastern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Burkina Faso' (clean: 'burkina faso')
#   -> Best match candidate: 'Burkina Faso'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BFA, SOV_A3=BFA, ADM0_A3=BFA
#   -> Additional: ISO_A2=BF, SUBUNIT=Burkina Faso, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Burma (Myanmar)' (clean: 'burma')
#   -> Best match candidate: 'Burma'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_CIAWF'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=MMR, SOV_A3=MMR, ADM0_A3=MMR
#   -> Additional: ISO_A2=MM, SUBUNIT=Myanmar, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Burundi' (clean: 'burundi')
#   -> Best match candidate: 'Burundi'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=BDI, SOV_A3=BDI, ADM0_A3=BDI
#   -> Additional: ISO_A2=BI, SUBUNIT=Burundi, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Cambodia' (clean: 'cambodia')
#   -> Best match candidate: 'Cambodia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=KHM, SOV_A3=KHM, ADM0_A3=KHM
#   -> Additional: ISO_A2=KH, SUBUNIT=Cambodia, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Cameroon' (clean: 'cameroon')
#   -> Best match candidate: 'Cameroon'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CMR, SOV_A3=CMR, ADM0_A3=CMR
#   -> Additional: ISO_A2=CM, SUBUNIT=Cameroon, SUBREGION=Middle Africa, CONTINENT=Africa
#
#
# Excel Country: 'Canada' (clean: 'canada')
#   -> Best match candidate: 'Canada'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CAN, SOV_A3=CAN, ADM0_A3=CAN
#   -> Additional: ISO_A2=CA, SUBUNIT=Canada, SUBREGION=Northern America, CONTINENT=North America
#
#
# Excel Country: 'Canary Islands' (clean: 'canary islands')
#   -> Best match candidate: 'Canary Islands'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ESC, SOV_A3=ESP, ADM0_A3=ESP
#   -> Additional: ISO_A2=-99, SUBUNIT=Canary Islands, SUBREGION=Southern Europe, CONTINENT=Africa
#
#
# Excel Country: 'Cape Verde' (clean: 'cape verde')
#   -> Best match candidate: 'Cape Verde'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=CPV, ADM0_A3=CPV
#   -> Additional: ISO_A2=CV, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Cayman Islands (U.K.)' (clean: 'cayman islands')
#   -> Best match candidate: 'Cayman Islands'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CYM, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=KY, SUBUNIT=None, SUBREGION=None, CONTINENT=North America
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Central African Republic' (clean: 'central african republic')
#   -> Best match candidate: 'Central African Republic'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CAF, SOV_A3=CAF, ADM0_A3=CAF
#   -> Additional: ISO_A2=CF, SUBUNIT=Central African Republic, SUBREGION=Middle Africa, CONTINENT=Africa
#
#
# Excel Country: 'Chad' (clean: 'chad')
#   -> Best match candidate: 'Chad'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TCD, SOV_A3=TCD, ADM0_A3=TCD
#   -> Additional: ISO_A2=TD, SUBUNIT=Chad, SUBREGION=Middle Africa, CONTINENT=Africa
#
#
# Excel Country: 'Chile' (clean: 'chile')
#   -> Best match candidate: 'Chile'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CHL, SOV_A3=CHL, ADM0_A3=CHL
#   -> Additional: ISO_A2=CL, SUBUNIT=Chile, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'China' (clean: 'china')
#   -> Best match candidate: 'China'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CHN, SOV_A3=CH1, ADM0_A3=CHN
#   -> Additional: ISO_A2=CN, SUBUNIT=China, SUBREGION=Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Christmas Island' (clean: 'christmas island')
#   -> Best match candidate: 'Christmas Island'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CXR, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=CX, SUBUNIT=None, SUBREGION=None, CONTINENT=Asia
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Cocos (Keeling) Islands' (clean: 'cocos islands')
#   -> Best match candidate: 'Island'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_DE'
#   -> Initial fuzzy score: 90 | Final score: 0
#   -> Codes: BRK_A3=ISL, SOV_A3=ISL, ADM0_A3=ISL
#   -> Additional: ISO_A2=IS, SUBUNIT=Iceland, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Colombia' (clean: 'colombia')
#   -> Best match candidate: 'Colombia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=COL, SOV_A3=COL, ADM0_A3=COL
#   -> Additional: ISO_A2=CO, SUBUNIT=Colombia, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Comoros' (clean: 'comoros')
#   -> Best match candidate: 'Comoros'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=COM, ADM0_A3=COM
#   -> Additional: ISO_A2=KM, SUBUNIT=Comoros, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Republic of Congo' (clean: 'republic of congo')
#   -> Best match candidate: 'Republic of the Congo'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 95 | Final score: 95
#   -> Codes: BRK_A3=COG, SOV_A3=COG, ADM0_A3=COG
#   -> Additional: ISO_A2=CG, SUBUNIT=Republic of the Congo, SUBREGION=Middle Africa, CONTINENT=Africa
#
#
# Excel Country: 'Cook Islands' (clean: 'cook islands')
#   -> Best match candidate: 'Cook Islands'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=COK, SOV_A3=NZ1, ADM0_A3=COK
#   -> Additional: ISO_A2=CK, SUBUNIT=Cook Islands, SUBREGION=Polynesia, CONTINENT=Oceania
#
#
# Excel Country: 'Costa Rica' (clean: 'costa rica')
#   -> Best match candidate: 'Costa Rica'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CRI, SOV_A3=CRI, ADM0_A3=CRI
#   -> Additional: ISO_A2=CR, SUBUNIT=Costa Rica, SUBREGION=Central America, CONTINENT=North America
#
#
# Excel Country: 'Côte d'Ivoire (Ivory Coast)' (clean: 'côte d'ivoire')
#   -> Best match candidate: 'Côte d'Ivoire'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CIV, SOV_A3=CIV, ADM0_A3=CIV
#   -> Additional: ISO_A2=CI, SUBUNIT=Ivory Coast, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Croatia' (clean: 'croatia')
#   -> Best match candidate: 'Croatia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=HRV, SOV_A3=HRV, ADM0_A3=HRV
#   -> Additional: ISO_A2=HR, SUBUNIT=Croatia, SUBREGION=Southern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Cuba' (clean: 'cuba')
#   -> Best match candidate: 'Cuba'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CUB, SOV_A3=CU1, ADM0_A3=CUB
#   -> Additional: ISO_A2=CU, SUBUNIT=Cuba, SUBREGION=Caribbean, CONTINENT=North America
#
#
# Excel Country: 'Curaçao' (clean: 'curaçao')
#   -> Best match candidate: 'Netherlands'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 90 | Final score: 100
#   -> Codes: BRK_A3=NLD, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=NL, SUBUNIT=None, SUBREGION=None, CONTINENT=Europe
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Cyprus' (clean: 'cyprus')
#   -> Best match candidate: 'Cyprus'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CYP, SOV_A3=CYP, ADM0_A3=CYP
#   -> Additional: ISO_A2=CY, SUBUNIT=Cyprus, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Czechia' (clean: 'czechia')
#   -> Best match candidate: 'Czechia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CZE, SOV_A3=CZE, ADM0_A3=CZE
#   -> Additional: ISO_A2=CZ, SUBUNIT=Czechia, SUBREGION=Eastern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Democratic Republic of Congo' (clean: 'democratic republic of congo')
#   -> Best match candidate: 'Democratic Republic of the Congo'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 95 | Final score: 95
#   -> Codes: BRK_A3=COD, SOV_A3=COD, ADM0_A3=COD
#   -> Additional: ISO_A2=CD, SUBUNIT=Democratic Republic of the Congo, SUBREGION=Middle Africa, CONTINENT=Africa
#
#
# Excel Country: 'Denmark' (clean: 'denmark')
#   -> Best match candidate: 'Denmark'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=DNK, SOV_A3=DN1, ADM0_A3=DNK
#   -> Additional: ISO_A2=DK, SUBUNIT=Denmark, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Djibouti' (clean: 'djibouti')
#   -> Best match candidate: 'Djibouti'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=DJI, SOV_A3=DJI, ADM0_A3=DJI
#   -> Additional: ISO_A2=DJ, SUBUNIT=Djibouti, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Dominica' (clean: 'dominica')
#   -> Best match candidate: 'Dominica'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=DMA, ADM0_A3=DMA
#   -> Additional: ISO_A2=DM, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Dominican Republic' (clean: 'dominican republic')
#   -> Best match candidate: 'Dominican Republic'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=DOM, SOV_A3=DOM, ADM0_A3=DOM
#   -> Additional: ISO_A2=DO, SUBUNIT=Dominican Republic, SUBREGION=Caribbean, CONTINENT=North America
#
#
# Excel Country: 'Easter Island' (clean: 'easter island')
#   -> Best match candidate: 'None'
#      from sheet: 'None', column: 'None'
#   -> Initial fuzzy score: 0 | Final score: 0
#   -> Codes: BRK_A3=None, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=None, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Ecuador' (clean: 'ecuador')
#   -> Best match candidate: 'Ecuador'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ECU, SOV_A3=ECU, ADM0_A3=ECU
#   -> Additional: ISO_A2=EC, SUBUNIT=Ecuador, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Egypt' (clean: 'egypt')
#   -> Best match candidate: 'Egypt'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=EGY, SOV_A3=EGY, ADM0_A3=EGY
#   -> Additional: ISO_A2=EG, SUBUNIT=Egypt, SUBREGION=Northern Africa, CONTINENT=Africa
#
#
# Excel Country: 'El Salvador' (clean: 'el salvador')
#   -> Best match candidate: 'El Salvador'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=SLV, SOV_A3=SLV, ADM0_A3=SLV
#   -> Additional: ISO_A2=SV, SUBUNIT=El Salvador, SUBREGION=Central America, CONTINENT=North America
#
#
# Excel Country: 'Equatorial Guinea' (clean: 'equatorial guinea')
#   -> Best match candidate: 'Equatorial Guinea'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GNQ, SOV_A3=GNQ, ADM0_A3=GNQ
#   -> Additional: ISO_A2=GQ, SUBUNIT=Equatorial Guinea, SUBREGION=Middle Africa, CONTINENT=Africa
#
#
# Excel Country: 'Eritrea' (clean: 'eritrea')
#   -> Best match candidate: 'Eritrea'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ERI, SOV_A3=ERI, ADM0_A3=ERI
#   -> Additional: ISO_A2=ER, SUBUNIT=Eritrea, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Estonia' (clean: 'estonia')
#   -> Best match candidate: 'Estonia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=EST, SOV_A3=EST, ADM0_A3=EST
#   -> Additional: ISO_A2=EE, SUBUNIT=Estonia, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Eswatini' (clean: 'eswatini')
#   -> Best match candidate: 'eSwatini'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=SWZ, SOV_A3=SWZ, ADM0_A3=SWZ
#   -> Additional: ISO_A2=SZ, SUBUNIT=eSwatini, SUBREGION=Southern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Ethiopia' (clean: 'ethiopia')
#   -> Best match candidate: 'Ethiopia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ETH, SOV_A3=ETH, ADM0_A3=ETH
#   -> Additional: ISO_A2=ET, SUBUNIT=Ethiopia, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Falkland Islands (Islas Malvinas)' (clean: 'falkland islands')
#   -> Best match candidate: 'Falkland Islands (Islas Malvinas)'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_CIAWF'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=B12, SOV_A3=GB1, ADM0_A3=FLK
#   -> Additional: ISO_A2=FK, SUBUNIT=Falkland Islands, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Faroe Islands' (clean: 'faroe islands')
#   -> Best match candidate: 'Faroe Islands'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME_CIAWF'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=FRO, SOV_A3=DN1, ADM0_A3=FRO
#   -> Additional: ISO_A2=FO, SUBUNIT=Faroe Islands, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Fiji' (clean: 'fiji')
#   -> Best match candidate: 'Fiji'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=FJI, SOV_A3=FJI, ADM0_A3=FJI
#   -> Additional: ISO_A2=FJ, SUBUNIT=Fiji, SUBREGION=Melanesia, CONTINENT=Oceania
#
#
# Excel Country: 'Finland' (clean: 'finland')
#   -> Best match candidate: 'Finland'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=FIN, SOV_A3=FI1, ADM0_A3=FIN
#   -> Additional: ISO_A2=FI, SUBUNIT=Finland, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'France' (clean: 'france')
#   -> Best match candidate: 'France'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=FRA, SOV_A3=FR1, ADM0_A3=FRA
#   -> Additional: ISO_A2=-99, SUBUNIT=France, SUBREGION=Western Europe, CONTINENT=Europe
#
#
# Excel Country: 'French Guiana' (clean: 'french guiana')
#   -> Best match candidate: 'French Guiana'
#      from sheet: 'ne_110m_admin_0_map_units', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GUF, SOV_A3=FR1, ADM0_A3=FRA
#   -> Additional: ISO_A2=FR-973, SUBUNIT=French Guiana, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'French Polynesia' (clean: 'french polynesia')
#   -> Best match candidate: 'French Polynesia'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=PYF, SOV_A3=FR1, ADM0_A3=PYF
#   -> Additional: ISO_A2=PF, SUBUNIT=French Polynesia, SUBREGION=Polynesia, CONTINENT=Oceania
#
#
# Excel Country: 'Gabon' (clean: 'gabon')
#   -> Best match candidate: 'Gabon'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GAB, SOV_A3=GAB, ADM0_A3=GAB
#   -> Additional: ISO_A2=GA, SUBUNIT=Gabon, SUBREGION=Middle Africa, CONTINENT=Africa
#
#
# Excel Country: 'Gambia, The' (clean: 'gambia, the')
#   -> Best match candidate: 'Gambia, The'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_CIAWF'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GMB, SOV_A3=GMB, ADM0_A3=GMB
#   -> Additional: ISO_A2=GM, SUBUNIT=Gambia, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Georgia' (clean: 'georgia')
#   -> Best match candidate: 'Georgia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GEO, SOV_A3=GEO, ADM0_A3=GEO
#   -> Additional: ISO_A2=GE, SUBUNIT=Georgia, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Germany' (clean: 'germany')
#   -> Best match candidate: 'Germany'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=DEU, SOV_A3=DEU, ADM0_A3=DEU
#   -> Additional: ISO_A2=DE, SUBUNIT=Germany, SUBREGION=Western Europe, CONTINENT=Europe
#
#
# Excel Country: 'Ghana' (clean: 'ghana')
#   -> Best match candidate: 'Ghana'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GHA, SOV_A3=GHA, ADM0_A3=GHA
#   -> Additional: ISO_A2=GH, SUBUNIT=Ghana, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Gibraltar' (clean: 'gibraltar')
#   -> Best match candidate: 'Gibraltar'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 72 | Final score: 100
#   -> Codes: BRK_A3=GIB, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=GI, SUBUNIT=None, SUBREGION=None, CONTINENT=Europe
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Greece' (clean: 'greece')
#   -> Best match candidate: 'Greece'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GRC, SOV_A3=GRC, ADM0_A3=GRC
#   -> Additional: ISO_A2=GR, SUBUNIT=Greece, SUBREGION=Southern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Greenland' (clean: 'greenland')
#   -> Best match candidate: 'Greenland'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GRL, SOV_A3=DN1, ADM0_A3=GRL
#   -> Additional: ISO_A2=GL, SUBUNIT=Greenland, SUBREGION=Northern America, CONTINENT=North America
#
#
# Excel Country: 'Grenada' (clean: 'grenada')
#   -> Best match candidate: 'Grenada'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=GRD, ADM0_A3=GRD
#   -> Additional: ISO_A2=GD, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Guadeloupe' (clean: 'guadeloupe')
#   -> Best match candidate: 'Guadeloupe'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 90 | Final score: 100
#   -> Codes: BRK_A3=GLP, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=GP, SUBUNIT=None, SUBREGION=None, CONTINENT=North America
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Guam (U.S.)' (clean: 'guam')
#   -> Best match candidate: 'Guam'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GUM, SOV_A3=US1, ADM0_A3=GUM
#   -> Additional: ISO_A2=GU, SUBUNIT=Guam, SUBREGION=Micronesia, CONTINENT=Oceania
#
#
# Excel Country: 'Guatemala' (clean: 'guatemala')
#   -> Best match candidate: 'Guatemala'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GTM, SOV_A3=GTM, ADM0_A3=GTM
#   -> Additional: ISO_A2=GT, SUBUNIT=Guatemala, SUBREGION=Central America, CONTINENT=North America
#
#
# Excel Country: 'Guinea' (clean: 'guinea')
#   -> Best match candidate: 'Guinea'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GIN, SOV_A3=GIN, ADM0_A3=GIN
#   -> Additional: ISO_A2=GN, SUBUNIT=Guinea, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Guinea-Bissau' (clean: 'guinea-bissau')
#   -> Best match candidate: 'Guinea-Bissau'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GNB, SOV_A3=GNB, ADM0_A3=GNB
#   -> Additional: ISO_A2=GW, SUBUNIT=Guinea-Bissau, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Guyana' (clean: 'guyana')
#   -> Best match candidate: 'Guyana'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GUY, SOV_A3=GUY, ADM0_A3=GUY
#   -> Additional: ISO_A2=GY, SUBUNIT=Guyana, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Haiti' (clean: 'haiti')
#   -> Best match candidate: 'Haiti'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=HTI, SOV_A3=HTI, ADM0_A3=HTI
#   -> Additional: ISO_A2=HT, SUBUNIT=Haiti, SUBREGION=Caribbean, CONTINENT=North America
#
#
# Excel Country: 'Honduras' (clean: 'honduras')
#   -> Best match candidate: 'Honduras'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=HND, SOV_A3=HND, ADM0_A3=HND
#   -> Additional: ISO_A2=HN, SUBUNIT=Honduras, SUBREGION=Central America, CONTINENT=North America
#
#
# Excel Country: 'Hong Kong (China)' (clean: 'hong kong')
#   -> Best match candidate: 'Hong Kong'
#      from sheet: 'ne_110m_populated_places', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=CHN, ADM0_A3=HKG
#   -> Additional: ISO_A2=HK, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Hungary' (clean: 'hungary')
#   -> Best match candidate: 'Hungary'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=HUN, SOV_A3=HUN, ADM0_A3=HUN
#   -> Additional: ISO_A2=HU, SUBUNIT=Hungary, SUBREGION=Eastern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Iceland' (clean: 'iceland')
#   -> Best match candidate: 'Iceland'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ISL, SOV_A3=ISL, ADM0_A3=ISL
#   -> Additional: ISO_A2=IS, SUBUNIT=Iceland, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'India' (clean: 'india')
#   -> Best match candidate: 'India'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=IND, SOV_A3=IND, ADM0_A3=IND
#   -> Additional: ISO_A2=IN, SUBUNIT=India, SUBREGION=Southern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Indonesia' (clean: 'indonesia')
#   -> Best match candidate: 'Indonesia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=IDN, SOV_A3=IDN, ADM0_A3=IDN
#   -> Additional: ISO_A2=ID, SUBUNIT=Indonesia, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Iran' (clean: 'iran')
#   -> Best match candidate: 'Iran'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=IRN, SOV_A3=IRN, ADM0_A3=IRN
#   -> Additional: ISO_A2=IR, SUBUNIT=Iran, SUBREGION=Southern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Iraq' (clean: 'iraq')
#   -> Best match candidate: 'Iraq'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=IRQ, SOV_A3=IRQ, ADM0_A3=IRQ
#   -> Additional: ISO_A2=IQ, SUBUNIT=Iraq, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Ireland' (clean: 'ireland')
#   -> Best match candidate: 'Ireland'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=IRL, SOV_A3=IRL, ADM0_A3=IRL
#   -> Additional: ISO_A2=IE, SUBUNIT=Ireland, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Israel' (clean: 'israel')
#   -> Best match candidate: 'Israel'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ISR, SOV_A3=IS1, ADM0_A3=ISR
#   -> Additional: ISO_A2=IL, SUBUNIT=Israel, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Italy' (clean: 'italy')
#   -> Best match candidate: 'Italy'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ITA, SOV_A3=ITA, ADM0_A3=ITA
#   -> Additional: ISO_A2=IT, SUBUNIT=Italy, SUBREGION=Southern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Jamaica' (clean: 'jamaica')
#   -> Best match candidate: 'Jamaica'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=JAM, SOV_A3=JAM, ADM0_A3=JAM
#   -> Additional: ISO_A2=JM, SUBUNIT=Jamaica, SUBREGION=Caribbean, CONTINENT=North America
#
#
# Excel Country: 'Japan' (clean: 'japan')
#   -> Best match candidate: 'Japan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=JPN, SOV_A3=JPN, ADM0_A3=JPN
#   -> Additional: ISO_A2=JP, SUBUNIT=Japan, SUBREGION=Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Jordan' (clean: 'jordan')
#   -> Best match candidate: 'Jordan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=JOR, SOV_A3=JOR, ADM0_A3=JOR
#   -> Additional: ISO_A2=JO, SUBUNIT=Jordan, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Kazakhstan' (clean: 'kazakhstan')
#   -> Best match candidate: 'Kazakhstan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=KAZ, SOV_A3=KA1, ADM0_A3=KAZ
#   -> Additional: ISO_A2=KZ, SUBUNIT=Kazakhstan, SUBREGION=Central Asia, CONTINENT=Asia
#
#
# Excel Country: 'Kenya' (clean: 'kenya')
#   -> Best match candidate: 'Kenya'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=KEN, SOV_A3=KEN, ADM0_A3=KEN
#   -> Additional: ISO_A2=KE, SUBUNIT=Kenya, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Kiribati' (clean: 'kiribati')
#   -> Best match candidate: 'Kiribati'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=KIR, ADM0_A3=KIR
#   -> Additional: ISO_A2=KI, SUBUNIT=Kiribati, SUBREGION=Micronesia, CONTINENT=Oceania
#
#
# Excel Country: 'Kosovo' (clean: 'kosovo')
#   -> Best match candidate: 'Kosovo'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=KOS, SOV_A3=KOS, ADM0_A3=KOS
#   -> Additional: ISO_A2=-99, SUBUNIT=Kosovo, SUBREGION=Southern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Kuwait' (clean: 'kuwait')
#   -> Best match candidate: 'Kuwait'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=KWT, SOV_A3=KWT, ADM0_A3=KWT
#   -> Additional: ISO_A2=KW, SUBUNIT=Kuwait, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Kyrgyzstan' (clean: 'kyrgyzstan')
#   -> Best match candidate: 'Kyrgyzstan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=KGZ, SOV_A3=KGZ, ADM0_A3=KGZ
#   -> Additional: ISO_A2=KG, SUBUNIT=Kyrgyzstan, SUBREGION=Central Asia, CONTINENT=Asia
#
#
# Excel Country: 'Laos' (clean: 'laos')
#   -> Best match candidate: 'Laos'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LAO, SOV_A3=LAO, ADM0_A3=LAO
#   -> Additional: ISO_A2=LA, SUBUNIT=Laos, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Latvia' (clean: 'latvia')
#   -> Best match candidate: 'Latvia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LVA, SOV_A3=LVA, ADM0_A3=LVA
#   -> Additional: ISO_A2=LV, SUBUNIT=Latvia, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Lebanon' (clean: 'lebanon')
#   -> Best match candidate: 'Lebanon'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LBN, SOV_A3=LBN, ADM0_A3=LBN
#   -> Additional: ISO_A2=LB, SUBUNIT=Lebanon, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Lesotho' (clean: 'lesotho')
#   -> Best match candidate: 'Lesotho'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LSO, SOV_A3=LSO, ADM0_A3=LSO
#   -> Additional: ISO_A2=LS, SUBUNIT=Lesotho, SUBREGION=Southern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Liberia' (clean: 'liberia')
#   -> Best match candidate: 'Liberia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LBR, SOV_A3=LBR, ADM0_A3=LBR
#   -> Additional: ISO_A2=LR, SUBUNIT=Liberia, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Libya' (clean: 'libya')
#   -> Best match candidate: 'Libya'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LBY, SOV_A3=LBY, ADM0_A3=LBY
#   -> Additional: ISO_A2=LY, SUBUNIT=Libya, SUBREGION=Northern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Liechtenstein' (clean: 'liechtenstein')
#   -> Best match candidate: 'Liechtenstein'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=LIE, ADM0_A3=LIE
#   -> Additional: ISO_A2=LI, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Lithuania' (clean: 'lithuania')
#   -> Best match candidate: 'Lithuania'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LTU, SOV_A3=LTU, ADM0_A3=LTU
#   -> Additional: ISO_A2=LT, SUBUNIT=Lithuania, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Luxembourg' (clean: 'luxembourg')
#   -> Best match candidate: 'Luxembourg'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LUX, SOV_A3=LUX, ADM0_A3=LUX
#   -> Additional: ISO_A2=LU, SUBUNIT=Luxembourg, SUBREGION=Western Europe, CONTINENT=Europe
#
#
# Excel Country: 'Macau' (clean: 'macau')
#   -> Best match candidate: 'None'
#      from sheet: 'None', column: 'None'
#   -> Initial fuzzy score: 100 | Final score: 0
#   -> Codes: BRK_A3=None, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=None, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Madagascar' (clean: 'madagascar')
#   -> Best match candidate: 'Madagascar'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=MDG, SOV_A3=MDG, ADM0_A3=MDG
#   -> Additional: ISO_A2=MG, SUBUNIT=Madagascar, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Madeira Islands' (clean: 'madeira islands')
#   -> Best match candidate: 'None'
#      from sheet: 'None', column: 'None'
#   -> Initial fuzzy score: 100 | Final score: 0
#   -> Codes: BRK_A3=None, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=None, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#
#
# Excel Country: 'Malawi' (clean: 'malawi')
#   -> Best match candidate: 'Malawi'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=MWI, SOV_A3=MWI, ADM0_A3=MWI
#   -> Additional: ISO_A2=MW, SUBUNIT=Malawi, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Malaysia' (clean: 'malaysia')
#   -> Best match candidate: 'Malaysia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=MYS, SOV_A3=MYS, ADM0_A3=MYS
#   -> Additional: ISO_A2=MY, SUBUNIT=Malaysia, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Maldives' (clean: 'maldives')
#   -> Best match candidate: 'Maldives'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=MDV, ADM0_A3=MDV
#   -> Additional: ISO_A2=MV, SUBUNIT=Maldives, SUBREGION=Southern Asia, CONTINENT=Seven seas (open ocean)
#
#
# Excel Country: 'Mali' (clean: 'mali')
#   -> Best match candidate: 'Mali'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=MLI, SOV_A3=MLI, ADM0_A3=MLI
#   -> Additional: ISO_A2=ML, SUBUNIT=Mali, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Malta' (clean: 'malta')
#   -> Best match candidate: 'Malta'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=MLT, ADM0_A3=MLT
#   -> Additional: ISO_A2=MT, SUBUNIT=Malta, SUBREGION=Southern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Marshall Islands' (clean: 'marshall islands')
#   -> Best match candidate: 'Marshall Islands'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=MHL, ADM0_A3=MHL
#   -> Additional: ISO_A2=MH, SUBUNIT=Marshall Islands, SUBREGION=Micronesia, CONTINENT=Oceania
#
#
# Excel Country: 'Martinique' (clean: 'martinique')
#   -> Best match candidate: 'Martinique'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=MTQ, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=MQ, SUBUNIT=None, SUBREGION=None, CONTINENT=North America
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Mauritania' (clean: 'mauritania')
#   -> Best match candidate: 'Mauritania'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=MRT, SOV_A3=MRT, ADM0_A3=MRT
#   -> Additional: ISO_A2=MR, SUBUNIT=Mauritania, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Mauritius' (clean: 'mauritius')
#   -> Best match candidate: 'Mauritius'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=MUS, ADM0_A3=MUS
#   -> Additional: ISO_A2=MU, SUBUNIT=Mauritius, SUBREGION=Eastern Africa, CONTINENT=Seven seas (open ocean)
#
#
# Excel Country: 'Mayotte' (clean: 'mayotte')
#   -> Best match candidate: 'Mayotte'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 90 | Final score: 100
#   -> Codes: BRK_A3=MYT, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=YT, SUBUNIT=None, SUBREGION=None, CONTINENT=Africa
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Mexico' (clean: 'mexico')
#   -> Best match candidate: 'Mexico'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=MEX, SOV_A3=MEX, ADM0_A3=MEX
#   -> Additional: ISO_A2=MX, SUBUNIT=Mexico, SUBREGION=Central America, CONTINENT=North America
#
#
# Excel Country: 'Federated States of Micronesia' (clean: 'federated states of micronesia')
#   -> Best match candidate: 'Federated States of Micronesia'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
# ...
#   -> Best match candidate: 'South Sudan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=SDS, SOV_A3=SDS, ADM0_A3=SDS
#   -> Additional: ISO_A2=SS, SUBUNIT=South Sudan, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Spain' (clean: 'spain')
#   -> Best match candidate: 'Spain'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ESP, SOV_A3=ESP, ADM0_A3=ESP
#   -> Additional: ISO_A2=ES, SUBUNIT=Spain, SUBREGION=Southern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Sri Lanka' (clean: 'sri lanka')
#   -> Best match candidate: 'Sri Lanka'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=LKA, SOV_A3=LKA, ADM0_A3=LKA
#   -> Additional: ISO_A2=LK, SUBUNIT=Sri Lanka, SUBREGION=Southern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Sudan' (clean: 'sudan')
#   -> Best match candidate: 'Sudan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=SDN, SOV_A3=SDN, ADM0_A3=SDN
#   -> Additional: ISO_A2=SD, SUBUNIT=Sudan, SUBREGION=Northern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Suriname' (clean: 'suriname')
#   -> Best match candidate: 'Suriname'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=SUR, SOV_A3=SUR, ADM0_A3=SUR
#   -> Additional: ISO_A2=SR, SUBUNIT=Suriname, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Sweden' (clean: 'sweden')
#   -> Best match candidate: 'Sweden'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=SWE, SOV_A3=SWE, ADM0_A3=SWE
#   -> Additional: ISO_A2=SE, SUBUNIT=Sweden, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'Switzerland' (clean: 'switzerland')
#   -> Best match candidate: 'Switzerland'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=CHE, SOV_A3=CHE, ADM0_A3=CHE
#   -> Additional: ISO_A2=CH, SUBUNIT=Switzerland, SUBREGION=Western Europe, CONTINENT=Europe
#
#
# Excel Country: 'Syria' (clean: 'syria')
#   -> Best match candidate: 'Syria'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=SYR, SOV_A3=SYR, ADM0_A3=SYR
#   -> Additional: ISO_A2=SY, SUBUNIT=Syria, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Taiwan' (clean: 'taiwan')
#   -> Best match candidate: 'Taiwan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TWN, SOV_A3=TWN, ADM0_A3=TWN
#   -> Additional: ISO_A2=CN-TW, SUBUNIT=Taiwan, SUBREGION=Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Tajikistan' (clean: 'tajikistan')
#   -> Best match candidate: 'Tajikistan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TJK, SOV_A3=TJK, ADM0_A3=TJK
#   -> Additional: ISO_A2=TJ, SUBUNIT=Tajikistan, SUBREGION=Central Asia, CONTINENT=Asia
#
#
# Excel Country: 'Tanzania' (clean: 'tanzania')
#   -> Best match candidate: 'Tanzania'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TZA, SOV_A3=TZA, ADM0_A3=TZA
#   -> Additional: ISO_A2=TZ, SUBUNIT=Tanzania, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Thailand' (clean: 'thailand')
#   -> Best match candidate: 'Thailand'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=THA, SOV_A3=THA, ADM0_A3=THA
#   -> Additional: ISO_A2=TH, SUBUNIT=Thailand, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Timor-Leste' (clean: 'timor-leste')
#   -> Best match candidate: 'Timor-Leste'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TLS, SOV_A3=TLS, ADM0_A3=TLS
#   -> Additional: ISO_A2=TL, SUBUNIT=East Timor, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Togo' (clean: 'togo')
#   -> Best match candidate: 'Togo'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TGO, SOV_A3=TGO, ADM0_A3=TGO
#   -> Additional: ISO_A2=TG, SUBUNIT=Togo, SUBREGION=Western Africa, CONTINENT=Africa
#
#
# Excel Country: 'Tokelau' (clean: 'tokelau')
#   -> Best match candidate: 'Tokelau'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 90 | Final score: 100
#   -> Codes: BRK_A3=TKL, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=TK, SUBUNIT=None, SUBREGION=None, CONTINENT=Oceania
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Tonga' (clean: 'tonga')
#   -> Best match candidate: 'Tonga'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=TON, ADM0_A3=TON
#   -> Additional: ISO_A2=TO, SUBUNIT=Tonga, SUBREGION=Polynesia, CONTINENT=Oceania
#
#
# Excel Country: 'Trinidad and Tobago' (clean: 'trinidad and tobago')
#   -> Best match candidate: 'Trinidad and Tobago'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TTO, SOV_A3=TTO, ADM0_A3=TTO
#   -> Additional: ISO_A2=TT, SUBUNIT=Trinidad and Tobago, SUBREGION=Caribbean, CONTINENT=North America
#
#
# Excel Country: 'Tunisia' (clean: 'tunisia')
#   -> Best match candidate: 'Tunisia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TUN, SOV_A3=TUN, ADM0_A3=TUN
#   -> Additional: ISO_A2=TN, SUBUNIT=Tunisia, SUBREGION=Northern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Turkey' (clean: 'turkey')
#   -> Best match candidate: 'Turkey'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TUR, SOV_A3=TUR, ADM0_A3=TUR
#   -> Additional: ISO_A2=TR, SUBUNIT=Turkey, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Turkmenistan' (clean: 'turkmenistan')
#   -> Best match candidate: 'Turkmenistan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TKM, SOV_A3=TKM, ADM0_A3=TKM
#   -> Additional: ISO_A2=TM, SUBUNIT=Turkmenistan, SUBREGION=Central Asia, CONTINENT=Asia
#
#
# Excel Country: 'Turks and Caicos Islands' (clean: 'turks and caicos islands')
#   -> Best match candidate: 'Turks and Caicos Islands'
#      from sheet: 'ne_110m_admin_0_tiny_countries', column: 'NAME_LONG'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=TCA, SOV_A3=GB1, ADM0_A3=TCA
#   -> Additional: ISO_A2=TC, SUBUNIT=Turks and Caicos Islands, SUBREGION=Caribbean, CONTINENT=North America
#
#
# Excel Country: 'Tuvalu' (clean: 'tuvalu')
#   -> Best match candidate: 'Tuvalu'
#      from sheet: 'ne_110m_populated_places', column: 'SOV0NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=None, SOV_A3=TUV, ADM0_A3=TUV
#   -> Additional: ISO_A2=TV, SUBUNIT=Tuvalu, SUBREGION=Polynesia, CONTINENT=Oceania
#
#
# Excel Country: 'Uganda' (clean: 'uganda')
#   -> Best match candidate: 'Uganda'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=UGA, SOV_A3=UGA, ADM0_A3=UGA
#   -> Additional: ISO_A2=UG, SUBUNIT=Uganda, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Ukraine' (clean: 'ukraine')
#   -> Best match candidate: 'Ukraine'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=UKR, SOV_A3=UKR, ADM0_A3=UKR
#   -> Additional: ISO_A2=UA, SUBUNIT=Ukraine, SUBREGION=Eastern Europe, CONTINENT=Europe
#
#
# Excel Country: 'United Arab Emirates' (clean: 'united arab emirates')
#   -> Best match candidate: 'United Arab Emirates'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ARE, SOV_A3=ARE, ADM0_A3=ARE
#   -> Additional: ISO_A2=AE, SUBUNIT=United Arab Emirates, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'United Kingdom' (clean: 'united kingdom')
#   -> Best match candidate: 'United Kingdom'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=GBR, SOV_A3=GB1, ADM0_A3=GBR
#   -> Additional: ISO_A2=GB, SUBUNIT=United Kingdom, SUBREGION=Northern Europe, CONTINENT=Europe
#
#
# Excel Country: 'United States of America' (clean: 'united states of america')
#   -> Best match candidate: 'United States of America'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=USA, SOV_A3=US1, ADM0_A3=USA
#   -> Additional: ISO_A2=US, SUBUNIT=United States, SUBREGION=Northern America, CONTINENT=North America
#
#
# Excel Country: 'Uruguay' (clean: 'uruguay')
#   -> Best match candidate: 'Uruguay'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=URY, SOV_A3=URY, ADM0_A3=URY
#   -> Additional: ISO_A2=UY, SUBUNIT=Uruguay, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Uzbekistan' (clean: 'uzbekistan')
#   -> Best match candidate: 'Uzbekistan'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=UZB, SOV_A3=UZB, ADM0_A3=UZB
#   -> Additional: ISO_A2=UZ, SUBUNIT=Uzbekistan, SUBREGION=Central Asia, CONTINENT=Asia
#
#
# Excel Country: 'Vanuatu' (clean: 'vanuatu')
#   -> Best match candidate: 'Vanuatu'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=VUT, SOV_A3=VUT, ADM0_A3=VUT
#   -> Additional: ISO_A2=VU, SUBUNIT=Vanuatu, SUBREGION=Melanesia, CONTINENT=Oceania
#
#
# Excel Country: 'Venezuela' (clean: 'venezuela')
#   -> Best match candidate: 'Venezuela'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=VEN, SOV_A3=VEN, ADM0_A3=VEN
#   -> Additional: ISO_A2=VE, SUBUNIT=Venezuela, SUBREGION=South America, CONTINENT=South America
#
#
# Excel Country: 'Vietnam' (clean: 'vietnam')
#   -> Best match candidate: 'Vietnam'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=VNM, SOV_A3=VNM, ADM0_A3=VNM
#   -> Additional: ISO_A2=VN, SUBUNIT=Vietnam, SUBREGION=South-Eastern Asia, CONTINENT=Asia
#
#
# Excel Country: 'Virgin Islands, British' (clean: 'virgin islands, british')
#   -> Best match candidate: 'Virgin Islands, British'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=VGB, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=VG, SUBUNIT=None, SUBREGION=None, CONTINENT=North America
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Virgin Islands, U.S.' (clean: 'virgin islands, u.s.')
#   -> Best match candidate: 'Virgin Islands, U.S.'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=VIR, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=VI, SUBUNIT=None, SUBREGION=None, CONTINENT=North America
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Wake Island' (clean: 'wake island')
#   -> Best match candidate: 'United States Minor Outlying Islands'
#      from sheet: 'pycountry', column: 'pycountry'
#   -> Initial fuzzy score: 90 | Final score: 100
#   -> Codes: BRK_A3=UMI, SOV_A3=None, ADM0_A3=None
#   -> Additional: ISO_A2=UM, SUBUNIT=None, SUBREGION=None, CONTINENT=None
#   -> Fallback using pycountry (and pycountry_convert) was used.
#
# Excel Country: 'Yemen' (clean: 'yemen')
#   -> Best match candidate: 'Yemen'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=YEM, SOV_A3=YEM, ADM0_A3=YEM
#   -> Additional: ISO_A2=YE, SUBUNIT=Yemen, SUBREGION=Western Asia, CONTINENT=Asia
#
#
# Excel Country: 'Zambia' (clean: 'zambia')
#   -> Best match candidate: 'Zambia'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ZMB, SOV_A3=ZMB, ADM0_A3=ZMB
#   -> Additional: ISO_A2=ZM, SUBUNIT=Zambia, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
# Excel Country: 'Zimbabwe' (clean: 'zimbabwe')
#   -> Best match candidate: 'Zimbabwe'
#      from sheet: 'ne_110m_admin_0_countries', column: 'NAME'
#   -> Initial fuzzy score: 100 | Final score: 100
#   -> Codes: BRK_A3=ZWE, SOV_A3=ZWE, ADM0_A3=ZWE
#   -> Additional: ISO_A2=ZW, SUBUNIT=Zimbabwe, SUBREGION=Eastern Africa, CONTINENT=Africa
#
#
#
# Final merged DataFrame head:
#                 Country                                 Entry Requirements  \
# 0           Afghanistan                                                NaN
# 1               Albania  Required for travelers ≥1 year old arriving fr...
# 2               Algeria  Required for travelers ≥9 months old arriving ...
# 3  American Samoa  (US)                                                NaN
# 4               Andorra                                                NaN
#
#   CDC Recommendations                                 Transmission Areas  \
# 0                 NaN  All areas <2,500 m (≈8,200 ft) elevation (Apri...
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
#
#   Drug Resistance                                            Species  \
# 0     Chloroquine  P. vivax(primarily)\nP. falciparum(less commonly)
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
#
#                         Recommended Chemoprophylaxis     Last Updated  \
# 0  Atovaquone-proguanil, doxycycline, mefloquine,...  October 4, 2024
# 1                                                NaN  October 4, 2024
# 2                                                NaN  October 4, 2024
# 3                                                NaN  October 4, 2024
# 4                                                NaN  October 4, 2024
#
#    CQ_resist  MQ_resist  ... ADM0_A3 ISO_A2      SUBUNIT        SUBREGION  \
# 0       True      False  ...     AFG     AF  Afghanistan    Southern Asia
# 1      False      False  ...     ALB     AL      Albania  Southern Europe
# 2      False      False  ...     DZA     DZ      Algeria  Northern Africa
# 3      False      False  ...    None     AS         None             None
# 4      False      False  ...     AND     AD         None             None
#
#   CONTINENT match_score                match_sheet match_source  \
# 0      Asia         100  ne_110m_admin_0_countries         NAME
# 1    Europe         100  ne_110m_admin_0_countries         NAME
# 2    Africa         100  ne_110m_admin_0_countries         NAME
# 3   Oceania         100                  pycountry    pycountry
# 4      None         100   ne_110m_populated_places         NAME
#
#   match_candidate pycountry_used
# 0     Afghanistan          False
# 1         Albania          False
# 2         Algeria          False
# 3  American Samoa           True
# 4         Andorra          False
#
# [5 rows x 26 columns]

# %%
# List every Country that originally had a fuzzy score ≤ 90 (before pycountry fallback).
low_score_countries = df[df["match_score"] < 100]["Country_Tableau"].unique()
print("\nCountries with original fuzzy score ≤ 100 (subject to pycountry fallback):")
print(low_score_countries)
# Out:
# Countries with original fuzzy score ≤ 100 (subject to pycountry fallback):
# ['Cocos (Keeling) Islands' 'Republic of Congo'
#  'Democratic Republic of Congo' 'Easter Island' 'Macau' 'Madeira Islands'
#  'Netherlands Antilles']

# %%
# Manual mappings for CONTINENT using normalized (lower-case) country names.
manual_continent = {
    'wake island': 'Oceania',
    'american samoa  (us)': 'Oceania',
    'andorra': 'Europe',
    'anguilla (u.k.)': 'North America',
    'antigua and barbuda': 'North America',
    'aruba': 'North America',
    'bonaire': 'North America',
    'cape verde': 'Africa',
    'cayman islands (u.k.)': 'North America',
    'christmas island': 'Oceania',
    'curaçao': 'North America',
    'dominica': 'North America',
    'gibraltar': 'Europe',
    'grenada': 'North America',
    'guadeloupe': 'North America',
    'hong kong (china)': 'Asia',
    'liechtenstein': 'Europe',
    'martinique': 'North America',
    'mayotte': 'Africa',
    'monaco': 'Europe',
    'montserrat': 'North America',
    'niue': 'Oceania',
    'norfolk island': 'Oceania',
    'réunion (france)': 'Africa',
    'saba': 'North America',
    'saint barthelemy': 'North America',
    'saint kitts and nevis': 'North America',
    'saint lucia': 'North America',
    'saint martin': 'North America',
    'saint vincent and the grenadines': 'North America',
    'san marino': 'Europe',
    'seychelles': 'Africa',
    'sint eustatius': 'North America',
    'sint maarten (dutch part)': 'North America',
    'tokelau': 'Oceania',
    'virgin islands, british': 'North America',
    'virgin islands, u.s.': 'North America'
}

# Manual mappings for SUBREGION using normalized (lower-case) country names.
manual_subregion = {
    'wake island': 'Micronesia',
    'american samoa  (us)': 'Polynesia',
    'american samoa': 'Polynesia', # American Samoa variants
    'andorra': 'Southern Europe',
    'anguilla (u.k.)': 'Caribbean',
    'antigua and barbuda': 'Caribbean',
    'aruba': 'Caribbean',
    'bonaire': 'Caribbean',
    'cape verde': 'Western Africa',
    'cayman islands (u.k.)': 'Caribbean',
    'christmas island': 'Oceania',
    'curaçao': 'Caribbean',
    'dominica': 'Caribbean',
    'gibraltar': 'Southern Europe',
    'grenada': 'Caribbean',
    'guadeloupe': 'Caribbean',
    'hong kong (china)': 'Eastern Asia',
    'liechtenstein': 'Western Europe',
    'martinique': 'Caribbean',
    'mayotte': 'Eastern Africa',
    'monaco': 'Western Europe',
    'montserrat': 'Caribbean',
    'niue': 'Polynesia',
    'norfolk island': 'Melanesia',
    'réunion (france)': 'Eastern Africa',
    'saba': 'Caribbean',
    'saint barthelemy': 'Caribbean',
    'saint kitts and nevis': 'Caribbean',
    'saint lucia': 'Caribbean',
    'saint martin': 'Caribbean',
    'saint vincent and the grenadines': 'Caribbean',
    'san marino': 'Southern Europe',
    'seychelles': 'Eastern Africa',
    'sint eustatius': 'Caribbean',
    'sint maarten (dutch part)': 'Caribbean',
    'tokelau': 'Polynesia',
    'virgin islands, british': 'Caribbean',
    'virgin islands, u.s.': 'Caribbean',
    # Additional mappings as requested:
    'cocos (keeling) islands': 'South-Eastern Asia',
    'macau': 'Eastern Asia'
}

# Helper functions for manual mapping using lower-case keys.
def get_manual_continent(country_name):
    if not country_name or not isinstance(country_name, str):
        return None
    return manual_continent.get(country_name.strip().lower())

def get_manual_subregion(country_name):
    if not country_name or not isinstance(country_name, str):
        return None
    return manual_subregion.get(country_name.strip().lower())

# Function to get continent from country name using pycountry_convert.
def get_continent_from_name(country):
    try:
        country_code = pc.country_name_to_country_alpha2(country)
        continent_code = pc.country_alpha2_to_continent_code(country_code)
        return pc.convert_continent_code_to_continent_name(continent_code)
    except Exception:
        return None

# Function to convert an alpha-3 country code to an alpha-2 code.
def convert_alpha3_to_alpha2(alpha3_code):
    try:
        country = pycountry.countries.get(alpha_3=alpha3_code)
        if country:
            return country.alpha_2
    except Exception:
        pass
    return None

# Helper function to get country name from ISO alpha-2 code.
def get_country_name_from_iso2(iso2):
    try:
        country = pycountry.countries.get(alpha_2=iso2)
        if country:
            return country.name
    except Exception:
        pass
    return None

# Updated function to determine continent from a row.
def get_continent_from_row(row):
    # 1. Check manual mapping using Country_Tableau.
    country_tableau = row.get("Country_Tableau", None)
    manual = get_manual_continent(country_tableau) if country_tableau else None
    if manual:
        return manual

    # 2. Try using Country_Tableau.
    if pd.notnull(country_tableau) and country_tableau.strip():
        continent = get_continent_from_name(country_tableau.strip())
        if continent:
            return continent

    # 3. Try using ISO_A2.
    iso_a2 = row.get("ISO_A2", None)
    if pd.notnull(iso_a2) and str(iso_a2).strip():
        iso2 = str(iso_a2).strip()
        try:
            continent_code = pc.country_alpha2_to_continent_code(iso2)
            continent = pc.convert_continent_code_to_continent_name(continent_code)
            if continent:
                return continent
        except Exception:
            pass

    # 4. Try using alpha-3 codes from BRK_A3, SOV_A3, ADM0_A3.
    for col in ["BRK_A3", "SOV_A3", "ADM0_A3"]:
        val = row.get(col, None)
        if pd.notnull(val) and str(val).strip():
            alpha3 = str(val).strip()
            iso2 = convert_alpha3_to_alpha2(alpha3)
            if iso2:
                try:
                    continent_code = pc.country_alpha2_to_continent_code(iso2)
                    continent = pc.convert_continent_code_to_continent_name(continent_code)
                    if continent:
                        return continent
                except Exception:
                    continue
    return None

# Updated function to determine subregion from a row.
def get_subregion_from_row(row):
    # 1. Check manual mapping using Country_Tableau.
    country_tableau = row.get("Country_Tableau", None)
    manual = get_manual_subregion(country_tableau) if country_tableau else None
    if manual:
        return manual
    
    country_name = None
    # 2. Use Country_Tableau if available.
    if pd.notnull(country_tableau) and country_tableau.strip():
        country_name = country_tableau.strip()
    
    # 3. If not, try ISO_A2.
    if not country_name:
        iso_a2 = row.get("ISO_A2", None)
        if pd.notnull(iso_a2) and str(iso_a2).strip():
            country_name = get_country_name_from_iso2(str(iso_a2).strip())
    
    # 4. If still not available, try using alpha-3 codes.
    if not country_name:
        for col in ["BRK_A3", "SOV_A3", "ADM0_A3"]:
            val = row.get(col, None)
            if pd.notnull(val) and str(val).strip():
                alpha3 = str(val).strip()
                try:
                    country = pycountry.countries.get(alpha_3=alpha3)
                    if country:
                        country_name = country.name
                        break
                except Exception:
                    continue
    
    # 5. Check manual mapping again with the resolved country name.
    if country_name:
        manual_sub = get_manual_subregion(country_name)
        if manual_sub:
            return manual_sub
    return None

# Fill missing CONTINENT values (where the field is blank or NaN)
mask_continent = df['CONTINENT'].isnull() | (df['CONTINENT'].astype(str).str.strip() == '')
df.loc[mask_continent, 'CONTINENT'] = df[mask_continent].apply(get_continent_from_row, axis=1)

# Fill missing SUBREGION values (where the field is blank or NaN)
mask_subregion = df['SUBREGION'].isnull() | (df['SUBREGION'].astype(str).str.strip() == '')
df.loc[mask_subregion, 'SUBREGION'] = df[mask_subregion].apply(get_subregion_from_row, axis=1)

# %%
# Export the final DataFrame to an Excel file
df.to_excel("yellow_fever_malaria_data_cleaned_yfcat_tableau_matched.xlsx", index=False)
